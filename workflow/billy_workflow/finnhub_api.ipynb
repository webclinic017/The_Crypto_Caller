# %%
import finnhub
import pandas as pd
import os
from dotenv import load_dotenv
import json
import datetime
from datetime import datetime, timedelta
import time

load_dotenv()
finnhub_api_key = os.getenv("FINNHUB_API_KEY")
if type(finnhub_api_key) == str:
    print('API OK')
else:
    print('API NOT OK', type(finnhub_api_key))
    print('Check your .env file for the FINNHUB_API_KEY value.')
    print('Sign-up and get an API key at https://finnhub.io/')

# Setup client
finnhub_client = finnhub.Client(api_key=finnhub_api_key)
# Out:
# API OK

# %%
symbol = pd.DataFrame(
    finnhub_client.crypto_symbols("COINBASE")
)
symbol
# Out:
#             description displaySymbol              symbol
# 0      COINBASE ADA/EUR       ADA/EUR    COINBASE:ADA-EUR
# 1    COINBASE MATIC/BTC     MATIC/BTC  COINBASE:MATIC-BTC
# 2      COINBASE NMR/EUR       NMR/EUR    COINBASE:NMR-EUR
# 3    COINBASE TRIBE/USD     TRIBE/USD  COINBASE:TRIBE-USD
# 4     COINBASE WCFG/GBP      WCFG/GBP   COINBASE:WCFG-GBP
# ..                  ...           ...                 ...
# 326   COINBASE ARPA/EUR      ARPA/EUR   COINBASE:ARPA-EUR
# 327    COINBASE BAL/BTC       BAL/BTC    COINBASE:BAL-BTC
# 328    COINBASE ADA/GBP       ADA/GBP    COINBASE:ADA-GBP
# 329   COINBASE LINK/EUR      LINK/EUR   COINBASE:LINK-EUR
# 330    COINBASE FIL/USD       FIL/USD    COINBASE:FIL-USD
#
# [331 rows x 3 columns]

# %%
# Time period of 86400 is going back 24 hours in seconds
beg_period = int(time.time()) - 86400
end_period = int(time.time())

res = pd.DataFrame(
    finnhub_client.crypto_candles("COINBASE:BTC-USD", "1", beg_period, end_period)
)
res
# Out:
#             c         h         l         o   s           t          v
# 0    64043.58  64049.90  63941.57  63945.12  ok  1636914240   1.650303
# 1    64104.53  64108.62  64020.54  64047.07  ok  1636914300   1.744883
# 2    64070.05  64150.79  64070.05  64104.53  ok  1636914360   4.804249
# 3    64074.01  64122.13  64059.33  64068.32  ok  1636914420   2.147876
# 4    64034.60  64074.01  64011.78  64074.01  ok  1636914480   2.123077
# ..        ...       ...       ...       ...  ..         ...        ...
# 284  64563.52  64576.06  64510.72  64548.81  ok  1636931280   9.292485
# 285  64583.96  64583.96  64560.62  64566.83  ok  1636931340   6.637719
# 286  64571.28  64591.33  64560.33  64583.95  ok  1636931400   1.697881
# 287  64598.49  64600.00  64571.28  64571.28  ok  1636931460   1.915524
# 288  64611.32  64673.71  64598.33  64598.50  ok  1636931520  21.476700
#
# [289 rows x 7 columns]

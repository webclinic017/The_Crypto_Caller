# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import pprint

listing_url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '16309f60-d6b0-492a-8596-06df4758b8c2',
}

session = Session()
session.headers.update(headers)

response = session.get(listing_url, params=parameters)

data = json.loads(response.text)
print(json.dumps(data, indent=4))
# crypto = []
# for row in data["data"]:
#     crypto.append(pd.Series(row))
# crypto = pd.DataFrame(
#     data=crypto,
#     columns = ["id", "name", "symbol", "quote"]
# )

#crypto_df['quote'][1]['USD']['price']

# crypto
# crypto = data['data'][2]['quote']['USD']['price']
# crypto

# for index, row in crypto.iterrows():
#   id = crypto.loc[0]
#   crypto_price = data['data'][f'{id}']['quote']['USD']['price'].astype(int)
#   crypto.loc[index, "price"] = crypto_price

# crypto
# Out:
# {
#     "status": {
#         "timestamp": "2021-11-19T04:26:15.912Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 154,
#         "credit_count": 5,
#         "notice": null,
#         "total_count": 7555
#     },
#     "data": [
#         {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "num_market_pairs": 8312,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channel",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
# ...

# %%
data['data']['quote'][1]['USD']['price']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-029c72188290> in <module>
# ----> 1 data['data']['quote'][1]['USD']['price']
#
# TypeError: list indices must be integers or slices, not str

# %%
d = {"USD":{"price":1}}

def lookup(dic,key,*keys):
    if keys:
        return lookup(dic.get(key,{}), *keys)
    return dic.get(key)
print(lookup(data, "quote", "USD", "price"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-cf72df69b714> in <module>
# ----> 1 d = {"USD":{"price":x}}
#       2
#       3 def lookup(dic,key,*keys):
#       4     if keys:
#       5         return lookup(dic.get(key,{}), *keys)
#
# NameError: name 'x' is not defined

# %%
# # crypto = pd.json_normalize(json['data'])
# quote = crypto['quote']
# quote[0]
# Out:
# {'USD': {'price': 55767.74779806264,
#   'volume_24h': 42109237174.582,
#   'volume_change_24h': 10.623,
#   'percent_change_1h': -0.84332734,
#   'percent_change_24h': -7.05724965,
#   'percent_change_7d': -14.07694108,
#   'percent_change_30d': -12.84199683,
#   'percent_change_60d': 22.21547882,
#   'percent_change_90d': 13.9818465,
#   'market_cap': 1052739932553.0485,
#   'market_cap_dominance': 43.0988,
#   'fully_diluted_market_cap': 1171122703759.32,
#   'last_updated': '2021-11-19T03:50:02.000Z'}}

# %%
amount = 1
symbol = 'BTC'
convert_url = 'https://pro-api.coinmarketcap.com/v1/tools/price-conversion'

parameters = {
    'amount': amount,
    'symbol': symbol,
    'convert': 'USD'
}
response = session.get(convert_url, params=parameters)
data = json.loads(response.text)
quote = []
for row in data['data']:
    quote.append(row)
quote
# Out:
# ['id', 'symbol', 'name', 'amount', 'last_updated', 'quote']

# %%
amount = 1
symbol = 'BTC'
convert_url = 'https://pro-api.coinmarketcap.com/v1/tools/price-conversion'

def get_crypto_prices():
    parameters = {
        'amount': amount,
        'symbol': cryptocurrency,
        'convert': 'USD'
    }
    response = session.get(convert_url, params=parameters)
    data = json.loads(response.text)
    quote = []
    for row in data['data']:
        quote.append(row)

    return quote
get_crypto_prices()
# Out:
# ['id', 'symbol', 'name', 'amount', 'last_updated', 'quote']

# %%
symbol_df = pd.DataFrame(crypto, columns=['symbol', 'id']).set_index(['id'])
symbol_df
# Out:
#      symbol
# id
# 1       BTC
# 1027    ETH
# 1839    BNB
# 825    USDT
# 2010    ADA
# ...     ...
# 8416    FXF
# 2658    MFG
# 6638  LAYER
# 8620  TOWER
# 1087    FCT
#
# [1000 rows x 1 columns]

# %%
crypto_df = pd.DataFrame(
    crypto,
    columns=['symbol','quote', 'id']
).set_index(['id'])
crypto_df
# Out:
#      symbol                                              quote
# id
# 1       BTC  {'USD': {'price': 56105.84031129357, 'volume_2...
# 1027    ETH  {'USD': {'price': 4011.141648935201, 'volume_2...
# 1839    BNB  {'USD': {'price': 530.7722062930106, 'volume_2...
# 825    USDT  {'USD': {'price': 1.0007560956303732, 'volume_...
# 2010    ADA  {'USD': {'price': 1.7655104736550424, 'volume_...
# ...     ...                                                ...
# 8416    FXF  {'USD': {'price': 0.20848489405842177, 'volume...
# 2658    MFG  {'USD': {'price': 0.04820183546882889, 'volume...
# 6638  LAYER  {'USD': {'price': 0.5948203340996289, 'volume_...
# 8620  TOWER  {'USD': {'price': 0.06244648756843113, 'volume...
# 1087    FCT  {'USD': {'price': 1.4639745355330445, 'volume_...
#
# [1000 rows x 2 columns]

# %%
quote_df = crypto_df['quote']
quote_list = quote_df.tolist()
quote_list
# Out:
# [{'USD': {'price': 56105.84031129357,
#    'volume_24h': 42262058662.14517,
#    'volume_change_24h': 9.4351,
#    'percent_change_1h': -1.19153561,
#    'percent_change_24h': -7.44565048,
#    'percent_change_7d': -13.68542654,
#    'percent_change_30d': -12.12123532,
#    'percent_change_60d': 23.34162325,
#    'percent_change_90d': 14.91385216,
#    'market_cap': 1059122178629.4766,
#    'market_cap_dominance': 43.0593,
#    'fully_diluted_market_cap': 1178222646537.16,
#    'last_updated': '2021-11-19T03:06:02.000Z'}},
#  {'USD': {'price': 4011.141648935201,
#    'volume_24h': 22371897369.277424,
#    'volume_change_24h': 6.1176,
#    'percent_change_1h': -0.88286715,
#    'percent_change_24h': -7.40926567,
#    'percent_change_7d': -16.12438681,
#    'percent_change_30d': 4.09270249,
#    'percent_change_60d': 26.01845567,
#    'percent_change_90d': 23.12467898,
#    'market_cap': 474914291174.708,
#    'market_cap_dominance': 19.3301,
# ...

# %%
cryptocurrency = 'BTC'
crypto_symbols = pd.DataFrame(
    columns = {
        'symbol' : crypto_df['symbol'],
    },
    data = crypto_df 
).set_index(['id'])
crypto_symbols
# Out:
#     symbol
# 0      BTC
# 1      ETH
# 2      BNB
# 3     USDT
# 4      ADA
# ..     ...
# 995    FXF
# 996    MFG
# 997  LAYER
# 998  TOWER
# 999    FCT
#
# [1000 rows x 1 columns]

# %%
# int corresponds to the crypto on the latest list
crypto_df['quote'][1]['USD']['price']
# Out:
# 4011.141648935201

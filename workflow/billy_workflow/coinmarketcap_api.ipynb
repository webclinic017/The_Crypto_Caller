# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'200',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '16309f60-d6b0-492a-8596-06df4758b8c2',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(json.dumps(data, indent=4))
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {
#     "status": {
#         "timestamp": "2021-11-16T23:38:43.690Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 29,
#         "credit_count": 1,
#         "notice": null,
#         "total_count": 7463
#     },
#     "data": [
#         {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "num_market_pairs": 8313,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channel",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "galaxy-digital-portfolio",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 18875262,
#             "total_supply": 18875262,
#             "platform": null,
#             "cmc_rank": 1,
#             "last_updated": "2021-11-16T23:37:02.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 60387.99777535291,
#                     "volume_24h": 47061675873.89147,
#                     "volume_change_24h": 52.5019,
#                     "percent_change_1h": -0.75143724,
#                     "percent_change_24h": -5.32509725,
#                     "percent_change_7d": -9.96550679,
#                     "percent_change_30d": -1.50395638,
#                     "percent_change_60d": 27.93829075,
#                     "percent_change_90d": 33.80774018,
#                     "market_cap": 1139839279665.2034,
#                     "market_cap_dominance": 43.3899,
#                     "fully_diluted_market_cap": 1268147953282.41,
#                     "last_updated": "2021-11-16T23:37:02.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1027,
#             "name": "Ethereum",
#             "symbol": "ETH",
#             "slug": "ethereum",
#             "num_market_pairs": 4646,
#             "date_added": "2015-08-07T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "smart-contracts",
#                 "ethereum-ecosystem",
#                 "binance-smart-chain",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "dcg-portfolio",
#                 "dragonfly-capital-portfolio",
#                 "electric-capital-portfolio",
#                 "fabric-ventures-portfolio",
#                 "framework-ventures-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kinetic-capital",
#                 "huobi-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "1confirmation-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "usv-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "multicoin-capital-portfolio",
#                 "paradigm-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 118369848.249,
#             "total_supply": 118369848.249,
#             "platform": null,
#             "cmc_rank": 2,
#             "last_updated": "2021-11-16T23:37:02.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 4245.859785948198,
#                     "volume_24h": 27571459762.393105,
#                     "volume_change_24h": 69.0541,
#                     "percent_change_1h": -1.06068559,
#                     "percent_change_24h": -7.1013705,
#                     "percent_change_7d": -10.19521123,
#                     "percent_change_30d": 11.06174689,
#                     "percent_change_60d": 25.06365618,
#                     "percent_change_90d": 38.90453162,
#                     "market_cap": 502581778549.2198,
#                     "market_cap_dominance": 19.1316,
#                     "fully_diluted_market_cap": 502581778549.22,
#                     "last_updated": "2021-11-16T23:37:02.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1839,
#             "name": "Binance Coin",
#             "symbol": "BNB",
#             "slug": "binance-coin",
#             "num_market_pairs": 554,
#             "date_added": "2017-07-25T00:00:00.000Z",
#             "tags": [
#                 "marketplace",
#                 "centralized-exchange",
#                 "payments",
#                 "smart-contracts",
#                 "binance-smart-chain",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio"
#             ],
#             "max_supply": 166801148,
#             "circulating_supply": 166801148,
#             "total_supply": 166801148,
#             "platform": null,
#             "cmc_rank": 3,
#             "last_updated": "2021-11-16T23:36:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 590.2523596465625,
#                     "volume_24h": 3758018206.273991,
#                     "volume_change_24h": 73.6094,
#                     "percent_change_1h": -0.41790583,
#                     "percent_change_24h": -7.06721405,
#                     "percent_change_7d": -7.24842521,
#                     "percent_change_30d": 25.96493106,
#                     "percent_change_60d": 45.50064573,
#                     "percent_change_90d": 46.39629072,
#                     "market_cap": 98454771198.7555,
#                     "market_cap_dominance": 3.7431,
#                     "fully_diluted_market_cap": 98454771198.76,
#                     "last_updated": "2021-11-16T23:36:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 825,
#             "name": "Tether",
#             "symbol": "USDT",
#             "slug": "tether",
#             "num_market_pairs": 19337,
#             "date_added": "2015-02-25T00:00:00.000Z",
#             "tags": [
#                 "payments",
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "binance-smart-chain",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 73761443730.02132,
#             "total_supply": 76357051672.20364,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
#             },
#             "cmc_rank": 4,
#             "last_updated": "2021-11-16T23:36:21.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0005055889085632,
#                     "volume_24h": 99388160962.09901,
#                     "volume_change_24h": 54.2648,
#                     "percent_change_1h": 0.00672762,
#                     "percent_change_24h": 0.03600103,
#                     "percent_change_7d": 0.0270352,
#                     "percent_change_30d": 0.01327461,
#                     "percent_change_60d": 0.08336558,
#                     "percent_change_90d": -0.00631548,
#                     "market_cap": 73798736697.85083,
#                     "market_cap_dominance": 2.8107,
#                     "fully_diluted_market_cap": 76395656950.62,
#                     "last_updated": "2021-11-16T23:36:21.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5426,
#             "name": "Solana",
#             "symbol": "SOL",
#             "slug": "solana",
#             "num_market_pairs": 183,
#             "date_added": "2020-04-10T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "platform",
#                 "solana-ecosystem",
#                 "cms-holdings-portfolio",
#                 "kinetic-capital",
#                 "alameda-research-portfolio",
#                 "multicoin-capital-portfolio",
#                 "k300-ventures-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 303467530.06758267,
#             "total_supply": 509195458.952264,
#             "platform": null,
#             "cmc_rank": 5,
#             "last_updated": "2021-11-16T23:37:05.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 221.00807872736777,
#                     "volume_24h": 3556176382.4262695,
#                     "volume_change_24h": 46.9197,
#                     "percent_change_1h": -1.61754239,
#                     "percent_change_24h": -7.43268342,
#                     "percent_change_7d": -7.65275085,
#                     "percent_change_30d": 38.82244707,
#                     "percent_change_60d": 50.55835288,
#                     "percent_change_90d": 195.2883756,
#                     "market_cap": 67068775776.37616,
#                     "market_cap_dominance": 2.5494,
#                     "fully_diluted_market_cap": 112536310079.74,
#                     "last_updated": "2021-11-16T23:37:05.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2010,
#             "name": "Cardano",
#             "symbol": "ADA",
#             "slug": "cardano",
#             "num_market_pairs": 303,
#             "date_added": "2017-10-01T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "dpos",
#                 "pos",
#                 "platform",
#                 "research",
#                 "smart-contracts",
#                 "staking",
#                 "binance-smart-chain",
#                 "cardano-ecosystem"
#             ],
#             "max_supply": 45000000000,
#             "circulating_supply": 33313246914.729,
#             "total_supply": 33719282563.077,
#             "platform": null,
#             "cmc_rank": 6,
#             "last_updated": "2021-11-16T23:36:21.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.889329408490415,
#                     "volume_24h": 3382200619.886174,
#                     "volume_change_24h": 137.2229,
#                     "percent_change_1h": -0.67343634,
#                     "percent_change_24h": -6.48072352,
#                     "percent_change_7d": -17.09086808,
#                     "percent_change_30d": -11.96474049,
#                     "percent_change_60d": -19.49752098,
#                     "percent_change_90d": -11.92515172,
#                     "market_cap": 62939697088.30009,
#                     "market_cap_dominance": 2.3924,
#                     "fully_diluted_market_cap": 85019823382.07,
#                     "last_updated": "2021-11-16T23:36:21.000Z"
#                 }
#             }
#         },
#         {
#             "id": 52,
#             "name": "XRP",
#             "symbol": "XRP",
#             "slug": "xrp",
#             "num_market_pairs": 628,
#             "date_added": "2013-08-04T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "binance-chain",
#                 "arrington-xrp-capital-portfolio",
#                 "galaxy-digital-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio"
#             ],
#             "max_supply": 100000000000,
#             "circulating_supply": 47158974920,
#             "total_supply": 99990145360,
#             "platform": null,
#             "cmc_rank": 7,
#             "last_updated": "2021-11-16T23:37:03.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0976986700325273,
#                     "volume_24h": 4864895935.221688,
#                     "volume_change_24h": 71.6522,
#                     "percent_change_1h": -0.6447696,
#                     "percent_change_24h": -6.66710114,
#                     "percent_change_7d": -12.96164096,
#                     "percent_change_30d": 0.52675577,
#                     "percent_change_60d": 3.22190724,
#                     "percent_change_90d": -6.60668868,
#                     "market_cap": 51766344049.78131,
#                     "market_cap_dominance": 1.9677,
#                     "fully_diluted_market_cap": 109769867003.25,
#                     "last_updated": "2021-11-16T23:37:03.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6636,
#             "name": "Polkadot",
#             "symbol": "DOT",
#             "slug": "polkadot-new",
#             "num_market_pairs": 251,
#             "date_added": "2020-08-19T00:00:00.000Z",
#             "tags": [
#                 "substrate",
#                 "polkadot",
#                 "binance-chain",
#                 "binance-smart-chain",
#                 "polkadot-ecosystem",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "arrington-xrp-capital-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "cms-holdings-portfolio",
#                 "coinfund-portfolio",
#                 "fabric-ventures-portfolio",
#                 "fenbushi-capital-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kinetic-capital",
#                 "1confirmation-portfolio",
#                 "placeholder-ventures-portfolio",
#                 "pantera-capital-portfolio",
#                 "exnetwork-capital-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 987579314.957085,
#             "total_supply": 1103303471.382273,
#             "platform": null,
#             "cmc_rank": 8,
#             "last_updated": "2021-11-16T23:37:07.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 41.16642658103441,
#                     "volume_24h": 2996562818.5487437,
#                     "volume_change_24h": 145.0074,
#                     "percent_change_1h": -1.21389099,
#                     "percent_change_24h": -8.6008471,
#                     "percent_change_7d": -19.16577211,
#                     "percent_change_30d": -1.51370734,
#                     "percent_change_60d": 25.26230258,
#                     "percent_change_90d": 68.85766002,
#                     "market_cap": 40655111362.1291,
#                     "market_cap_dominance": 1.5472,
#                     "fully_diluted_market_cap": 45419061351.26,
#                     "last_updated": "2021-11-16T23:37:07.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3408,
#             "name": "USD Coin",
#             "symbol": "USDC",
#             "slug": "usd-coin",
#             "num_market_pairs": 1552,
#             "date_added": "2018-10-08T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "binance-smart-chain",
#                 "fantom-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 34424351583.84238,
#             "total_supply": 34424351583.84238,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"
#             },
#             "cmc_rank": 9,
#             "last_updated": "2021-11-16T23:37:06.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0000585050603574,
#                     "volume_24h": 6479887157.171949,
#                     "volume_change_24h": 55.4665,
#                     "percent_change_1h": -0.02137738,
#                     "percent_change_24h": 0.01764907,
#                     "percent_change_7d": -0.01332228,
#                     "percent_change_30d": -0.03285701,
#                     "percent_change_60d": 0.01716737,
#                     "percent_change_90d": -0.02265761,
#                     "market_cap": 34426365582.60956,
#                     "market_cap_dominance": 1.3112,
#                     "fully_diluted_market_cap": 34426365582.61,
#                     "last_updated": "2021-11-16T23:37:06.000Z"
#                 }
#             }
#         },
#         {
#             "id": 74,
#             "name": "Dogecoin",
#             "symbol": "DOGE",
#             "slug": "dogecoin",
#             "num_market_pairs": 409,
#             "date_added": "2013-12-15T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "memes",
#                 "payments",
#                 "binance-smart-chain",
#                 "doggone-doggerel"
#             ],
#             "max_supply": null,
#             "circulating_supply": 132140677597.90349,
#             "total_supply": 132140677597.90349,
#             "platform": null,
#             "cmc_rank": 10,
#             "last_updated": "2021-11-16T23:37:03.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.2386403755147686,
#                     "volume_24h": 2243363738.78997,
#                     "volume_change_24h": 116.9874,
#                     "percent_change_1h": -0.8611781,
#                     "percent_change_24h": -7.30607642,
#                     "percent_change_7d": -12.95222894,
#                     "percent_change_30d": 0.46241255,
#                     "percent_change_60d": -0.543832,
#                     "percent_change_90d": -23.04604396,
#                     "market_cap": 31534100922.73966,
#                     "market_cap_dominance": 1.2001,
#                     "fully_diluted_market_cap": 31534100922.74,
#                     "last_updated": "2021-11-16T23:37:03.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5994,
#             "name": "SHIBA INU",
#             "symbol": "SHIB",
#             "slug": "shiba-inu",
#             "num_market_pairs": 160,
#             "date_added": "2020-08-01T00:00:00.000Z",
#             "tags": [
#                 "memes",
#                 "doggone-doggerel"
#             ],
#             "max_supply": null,
#             "circulating_supply": 549095509738353,
#             "total_supply": 589738956207003.8,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce"
#             },
#             "cmc_rank": 11,
#             "last_updated": "2021-11-16T23:36:21.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 4.8782538873173854e-05,
#                     "volume_24h": 3950186115.8000774,
#                     "volume_change_24h": 52.894,
#                     "percent_change_1h": -1.04681503,
#                     "percent_change_24h": -8.76691751,
#                     "percent_change_7d": -11.37299312,
#                     "percent_change_30d": 77.69321222,
#                     "percent_change_60d": 484.33348387,
#                     "percent_change_90d": 498.17569627,
#                     "market_cap": 26786273048.89642,
#                     "market_cap_dominance": 1.0194,
#                     "fully_diluted_market_cap": 28768963556.19,
#                     "last_updated": "2021-11-16T23:36:21.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5805,
#             "name": "Avalanche",
#             "symbol": "AVAX",
#             "slug": "avalanche",
#             "num_market_pairs": 113,
#             "date_added": "2020-07-13T00:00:00.000Z",
#             "tags": [
#                 "defi",
#                 "smart-contracts",
#                 "binance-smart-chain",
#                 "polychain-capital-portfolio",
#                 "avalanche-ecosystem",
#                 "cms-holdings-portfolio",
#                 "dragonfly-capital-portfolio"
#             ],
#             "max_supply": 720000000,
#             "circulating_supply": 220286577.20755112,
#             "total_supply": 391128418.8675511,
#             "platform": null,
#             "cmc_rank": 12,
#             "last_updated": "2021-11-16T23:37:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 100.37169739936351,
#                     "volume_24h": 1842007934.967029,
#                     "volume_change_24h": 52.2917,
#                     "percent_change_1h": -0.9637902,
#                     "percent_change_24h": 5.86245657,
#                     "percent_change_7d": 13.3262801,
#                     "percent_change_30d": 79.3320416,
#                     "percent_change_60d": 42.82492157,
#                     "percent_change_90d": 234.32509421,
#                     "market_cap": 22110537668.617847,
#                     "market_cap_dominance": 0.8417,
#                     "fully_diluted_market_cap": 72267622127.54,
#                     "last_updated": "2021-11-16T23:37:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4172,
#             "name": "Terra",
#             "symbol": "LUNA",
#             "slug": "terra-luna",
#             "num_market_pairs": 104,
#             "date_added": "2019-07-26T00:00:00.000Z",
#             "tags": [
#                 "cosmos-ecosystem",
#                 "store-of-value",
#                 "defi",
#                 "payments",
#                 "coinbase-ventures-portfolio",
#                 "binance-labs-portfolio",
#                 "solana-ecosystem",
#                 "arrington-xrp-capital-portfolio",
#                 "hashkey-capital-portfolio",
#                 "kinetic-capital",
#                 "huobi-capital-portfolio",
#                 "pantera-capital-portfolio",
#                 "terra-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 432071611.8946121,
#             "total_supply": 909122350.434096,
#             "platform": null,
#             "cmc_rank": 13,
#             "last_updated": "2021-11-16T23:37:03.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 43.58338393733085,
#                     "volume_24h": 1308821461.708711,
#                     "volume_change_24h": 159.1173,
#                     "percent_change_1h": -1.18632647,
#                     "percent_change_24h": -9.78781828,
#                     "percent_change_7d": -13.71118498,
#                     "percent_change_30d": 21.18986362,
#                     "percent_change_60d": 26.64833736,
#                     "percent_change_90d": 39.26104672,
#                     "market_cap": 18831142949.624287,
#                     "market_cap_dominance": 0.7158,
#                     "fully_diluted_market_cap": 39622628444.98,
#                     "last_updated": "2021-11-16T23:37:03.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2,
#             "name": "Litecoin",
#             "symbol": "LTC",
#             "slug": "litecoin",
#             "num_market_pairs": 678,
#             "date_added": "2013-04-28T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "scrypt",
#                 "medium-of-exchange",
#                 "binance-chain",
#                 "binance-smart-chain"
#             ],
#             "max_supply": 84000000,
#             "circulating_supply": 68988607.5271252,
#             "total_supply": 84000000,
#             "platform": null,
#             "cmc_rank": 14,
#             "last_updated": "2021-11-16T23:37:02.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 232.19935613167,
#                     "volume_24h": 4045421707.400135,
#                     "volume_change_24h": 41.4295,
#                     "percent_change_1h": -1.17556018,
#                     "percent_change_24h": -12.06868065,
#                     "percent_change_7d": -11.92580507,
#                     "percent_change_30d": 26.73819285,
#                     "percent_change_60d": 29.21236283,
#                     "percent_change_90d": 37.16588519,
#                     "market_cap": 16019110248.218952,
#                     "market_cap_dominance": 0.6101,
#                     "fully_diluted_market_cap": 19504745915.06,
#                     "last_updated": "2021-11-16T23:37:02.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3717,
#             "name": "Wrapped Bitcoin",
#             "symbol": "WBTC",
#             "slug": "wrapped-bitcoin",
#             "num_market_pairs": 173,
#             "date_added": "2019-01-30T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "defi",
#                 "wrapped-tokens",
#                 "fantom-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 239132.08155071,
#             "total_supply": 239132.08155071,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x2260fac5e5542a773aa44fbcfedf7c193bc2c599"
#             },
#             "cmc_rank": 15,
#             "last_updated": "2021-11-16T23:37:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 59277.9648557776,
#                     "volume_24h": 395788188.1562697,
#                     "volume_change_24h": 78.7659,
#                     "percent_change_1h": -0.22180686,
#                     "percent_change_24h": -6.44732525,
#                     "percent_change_7d": -11.73107248,
#                     "percent_change_30d": -3.29205729,
#                     "percent_change_60d": 25.64253864,
#                     "percent_change_90d": 31.65405576,
#                     "market_cap": 14175263126.05193,
#                     "market_cap_dominance": 0.5388,
#                     "fully_diluted_market_cap": 14175263126.05,
#                     "last_updated": "2021-11-16T23:37:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 7083,
#             "name": "Uniswap",
#             "symbol": "UNI",
#             "slug": "uniswap",
#             "num_market_pairs": 285,
#             "date_added": "2020-09-17T00:00:00.000Z",
#             "tags": [
#                 "decentralized-exchange",
#                 "defi",
#                 "dao",
#                 "yield-farming",
#                 "amm",
#                 "binance-smart-chain",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "governance",
#                 "blockchain-capital-portfolio",
#                 "defiance-capital-portfolio",
#                 "alameda-research-portfolio",
#                 "a16z-portfolio",
#                 "pantera-capital-portfolio",
#                 "parafi-capital",
#                 "paradigm-portfolio",
#                 "arbitrum-ecosytem"
#             ],
#             "max_supply": 1000000000,
#             "circulating_supply": 627823666.7726728,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x1f9840a85d5af5bf1d1762f925bdaddc4201f984"
#             },
#             "cmc_rank": 17,
#             "last_updated": "2021-11-16T23:36:23.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 21.86446174751975,
#                     "volume_24h": 539696824.4100175,
#                     "volume_change_24h": 103.9267,
#                     "percent_change_1h": -0.61492631,
#                     "percent_change_24h": -8.90516456,
#                     "percent_change_7d": -17.12639909,
#                     "percent_change_30d": -15.32325607,
#                     "percent_change_60d": -9.85454216,
#                     "percent_change_90d": -18.75036219,
#                     "market_cap": 13727026546.338692,
#                     "market_cap_dominance": 0.5228,
#                     "fully_diluted_market_cap": 21864461747.52,
#                     "last_updated": "2021-11-16T23:36:23.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1975,
#             "name": "Chainlink",
#             "symbol": "LINK",
#             "slug": "chainlink",
#             "num_market_pairs": 473,
#             "date_added": "2017-09-20T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "defi",
#                 "oracles",
#                 "smart-contracts",
#                 "substrate",
#                 "polkadot",
#                 "binance-smart-chain",
#                 "polkadot-ecosystem",
#                 "avalanche-ecosystem",
#                 "solana-ecosystem",
#                 "framework-ventures-portfolio",
#                 "polygon-ecosystem",
#                 "fantom-ecosystem",
#                 "near-protocol-ecosystem"
#             ],
#             "max_supply": 1000000000,
#             "circulating_supply": 465509553.9174637,
#             "total_supply": 1000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x514910771af9ca656af840dff83e8264ecf986ca"
#             },
#             "cmc_rank": 16,
#             "last_updated": "2021-11-16T23:36:21.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 29.522186780860416,
#                     "volume_24h": 1720282171.205027,
#                     "volume_change_24h": 107.6858,
#                     "percent_change_1h": -1.23829273,
#                     "percent_change_24h": -8.21748951,
#                     "percent_change_7d": -12.91516536,
#                     "percent_change_30d": 11.76373771,
#                     "percent_change_60d": 6.61805334,
#                     "percent_change_90d": 13.9170661,
#                     "market_cap": 13742859999.026377,
#                     "market_cap_dominance": 0.5224,
#                     "fully_diluted_market_cap": 29522186780.86,
#                     "last_updated": "2021-11-16T23:36:21.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4687,
#             "name": "Binance USD",
#             "symbol": "BUSD",
#             "slug": "binance-usd",
#             "num_market_pairs": 1551,
#             "date_added": "2019-09-20T00:00:00.000Z",
#             "tags": [
#                 "stablecoin",
#                 "asset-backed-stablecoin",
#                 "binance-chain",
#                 "binance-smart-chain"
#             ],
#             "max_supply": null,
#             "circulating_supply": 12873967472.64,
#             "total_supply": 12873967472.64,
#             "platform": {
#                 "id": 1839,
#                 "name": "Binance Chain (BEP2)",
#                 "symbol": "BNB",
#                 "slug": "binance-coin",
#                 "token_address": "BUSD-BD1"
#             },
#             "cmc_rank": 18,
#             "last_updated": "2021-11-16T23:37:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.0000479833816909,
#                     "volume_24h": 9128644412.232164,
#                     "volume_change_24h": 58.366,
#                     "percent_change_1h": 0.00539734,
#                     "percent_change_24h": -0.00083934,
#                     "percent_change_7d": 0.00304669,
#                     "percent_change_30d": -0.04091068,
#                     "percent_change_60d": 0.04591744,
#                     "percent_change_90d": -0.03012995,
#                     "market_cap": 12874585209.135115,
#                     "market_cap_dominance": 0.4903,
#                     "fully_diluted_market_cap": 12874585209.14,
#                     "last_updated": "2021-11-16T23:37:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1831,
#             "name": "Bitcoin Cash",
#             "symbol": "BCH",
#             "slug": "bitcoin-cash",
#             "num_market_pairs": 524,
#             "date_added": "2017-07-23T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "marketplace",
#                 "medium-of-exchange",
#                 "store-of-value",
#                 "enterprise-solutions",
#                 "payments",
#                 "binance-chain",
#                 "binance-smart-chain"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 18902406.25,
#             "total_supply": 18902406.25,
#             "platform": null,
#             "cmc_rank": 19,
#             "last_updated": "2021-11-16T23:36:16.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 603.700821796061,
#                     "volume_24h": 1663123827.0022724,
#                     "volume_change_24h": 52.8857,
#                     "percent_change_1h": -0.8014173,
#                     "percent_change_24h": -9.54031291,
#                     "percent_change_7d": -15.85810597,
#                     "percent_change_30d": -1.0794522,
#                     "percent_change_60d": -2.58977689,
#                     "percent_change_90d": -5.67239446,
#                     "market_cap": 11411398187.047998,
#                     "market_cap_dominance": 0.4346,
#                     "fully_diluted_market_cap": 12677717257.72,
#                     "last_updated": "2021-11-16T23:36:16.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3890,
#             "name": "Polygon",
#             "symbol": "MATIC",
#             "slug": "polygon",
#             "num_market_pairs": 253,
#             "date_added": "2019-04-28T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "enterprise-solutions",
#                 "state-channel",
#                 "binance-smart-chain",
#                 "coinbase-ventures-portfolio",
#                 "binance-launchpad",
#                 "binance-labs-portfolio",
#                 "polygon-ecosystem"
#             ],
#             "max_supply": 10000000000,
#             "circulating_supply": 6942890165.27,
#             "total_supply": 10000000000,
#             "platform": null,
#             "cmc_rank": 20,
#             "last_updated": "2021-11-16T23:36:21.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.5762158899834646,
#                     "volume_24h": 1293154021.7108338,
#                     "volume_change_24h": 92.8971,
#                     "percent_change_1h": -0.21552062,
#                     "percent_change_24h": -7.18701003,
#                     "percent_change_7d": -10.78689152,
#                     "percent_change_30d": 9.25241792,
#                     "percent_change_60d": 11.31978076,
#                     "percent_change_90d": 15.88515239,
#                     "market_cap": 10943493800.908497,
#                     "market_cap_dominance": 0.4166,
#                     "fully_diluted_market_cap": 15762158899.83,
#                     "last_updated": "2021-11-16T23:36:21.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4030,
#             "name": "Algorand",
#             "symbol": "ALGO",
#             "slug": "algorand",
#             "num_market_pairs": 157,
#             "date_added": "2019-06-20T00:00:00.000Z",
#             "tags": [
#                 "pos",
#                 "platform",
#                 "research",
#                 "smart-contracts",
#                 "arrington-xrp-capital-portfolio",
#                 "kinetic-capital",
#                 "usv-portfolio",
#                 "multicoin-capital-portfolio",
#                 "exnetwork-capital-portfolio"
#             ],
#             "max_supply": 10000000000,
#             "circulating_supply": 6250897203.072528,
#             "total_supply": 6712630940.659888,
#             "platform": null,
#             "cmc_rank": 21,
#             "last_updated": "2021-11-16T23:36:20.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 1.7380179938925093,
#                     "volume_24h": 787253508.1750671,
#                     "volume_change_24h": 67.4836,
#                     "percent_change_1h": -0.49057847,
#                     "percent_change_24h": -8.52313864,
#                     "percent_change_7d": -11.13914664,
#                     "percent_change_30d": -1.28502396,
#                     "percent_change_60d": -9.00163371,
#                     "percent_change_90d": 84.76357324,
#                     "market_cap": 10864171816.912413,
#                     "market_cap_dominance": 0.4138,
#                     "fully_diluted_market_cap": 17380179938.93,
#                     "last_updated": "2021-11-16T23:36:20.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3635,
#             "name": "Crypto.com Coin",
#             "symbol": "CRO",
#             "slug": "crypto-com-coin",
#             "num_market_pairs": 110,
#             "date_added": "2018-12-14T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "cosmos-ecosystem",
#                 "centralized-exchange",
#                 "mobile",
#                 "payments"
#             ],
#             "max_supply": 30263013692,
#             "circulating_supply": 25263013692,
#             "total_supply": 30263013692,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b"
#             },
#             "cmc_rank": 22,
#             "last_updated": "2021-11-16T23:37:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.41884253551897455,
#                     "volume_24h": 459779957.7061598,
#                     "volume_change_24h": -52.2273,
#                     "percent_change_1h": -1.43298392,
#                     "percent_change_24h": -6.98255518,
#                     "percent_change_7d": 18.02886782,
#                     "percent_change_30d": 122.80823174,
#                     "percent_change_60d": 122.98476339,
#                     "percent_change_90d": 191.86136989,
#                     "market_cap": 10581224709.607851,
#                     "market_cap_dominance": 0.4028,
#                     "fully_diluted_market_cap": 12675437387.2,
#                     "last_updated": "2021-11-16T23:37:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3077,
#             "name": "VeChain",
#             "symbol": "VET",
#             "slug": "vechain",
#             "num_market_pairs": 149,
#             "date_added": "2017-08-22T00:00:00.000Z",
#             "tags": [
#                 "logistics",
#                 "data-provenance",
#                 "iot",
#                 "smart-contracts",
#                 "fenbushi-capital-portfolio"
#             ],
#             "max_supply": 86712634466,
#             "circulating_supply": 64315576989,
#             "total_supply": 86712634466,
#             "platform": null,
#             "cmc_rank": 23,
#             "last_updated": "2021-11-16T23:37:02.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.14632618331452413,
#                     "volume_24h": 1146244523.6462948,
#                     "volume_change_24h": 19.3963,
#                     "percent_change_1h": -2.00777289,
#                     "percent_change_24h": -10.7912751,
#                     "percent_change_7d": -14.90517977,
#                     "percent_change_30d": 20.2921561,
#                     "percent_change_60d": 30.8567531,
#                     "percent_change_90d": 19.6613891,
#                     "market_cap": 9411052908.471804,
#                     "market_cap_dominance": 0.3584,
#                     "fully_diluted_market_cap": 12688328846.56,
#                     "last_updated": "2021-11-16T23:37:02.000Z"
#                 }
#             }
#         },
#         {
#             "id": 512,
#             "name": "Stellar",
#             "symbol": "XLM",
#             "slug": "stellar",
#             "num_market_pairs": 322,
#             "date_added": "2014-08-05T00:00:00.000Z",
#             "tags": [
#                 "medium-of-exchange",
#                 "enterprise-solutions",
#                 "decentralized-exchange",
#                 "smart-contracts",
#                 "hashkey-capital-portfolio"
#             ],
#             "max_supply": 50001806812,
#             "circulating_supply": 24286104252.359505,
#             "total_supply": 50001802590.97515,
#             "platform": null,
#             "cmc_rank": 24,
#             "last_updated": "2021-11-16T23:37:07.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.34631917990218,
#                     "volume_24h": 950649124.4287075,
#                     "volume_change_24h": 42.1783,
#                     "percent_change_1h": -0.7632809,
#                     "percent_change_24h": -8.33078383,
#                     "percent_change_7d": -16.18504878,
#                     "percent_change_30d": -9.83981166,
#                     "percent_change_60d": 8.46189877,
#                     "percent_change_90d": -0.33146882,
#                     "market_cap": 8410743707.69599,
#                     "market_cap_dominance": 0.3201,
#                     "fully_diluted_market_cap": 17316584728.76,
#                     "last_updated": "2021-11-16T23:37:07.000Z"
#                 }
#             }
#         },
#         {
#             "id": 6783,
#             "name": "Axie Infinity",
#             "symbol": "AXS",
#             "slug": "axie-infinity",
#             "num_market_pairs": 133,
#             "date_added": "2020-08-31T00:00:00.000Z",
#             "tags": [
#                 "collectibles-nfts",
#                 "gaming",
#                 "binance-launchpad",
#                 "metaverse",
#                 "defiance-capital-portfolio",
#                 "play-to-earn",
#                 "animoca-brands-portfolio"
#             ],
#             "max_supply": 270000000,
#             "circulating_supply": 60907500,
#             "total_supply": 270000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xbb0e17ef65f82ab018d8edd776e8dd940327b28b"
#             },
#             "cmc_rank": 25,
#             "last_updated": "2021-11-16T23:37:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 135.06561341701422,
#                     "volume_24h": 600016674.9920732,
#                     "volume_change_24h": 67.0693,
#                     "percent_change_1h": -1.22398664,
#                     "percent_change_24h": -5.42850339,
#                     "percent_change_7d": -10.24771465,
#                     "percent_change_30d": 8.69804255,
#                     "percent_change_60d": 106.11793498,
#                     "percent_change_90d": 91.67221836,
#                     "market_cap": 8226508849.196794,
#                     "market_cap_dominance": 0.3131,
#                     "fully_diluted_market_cap": 36467715622.59,
#                     "last_updated": "2021-11-16T23:37:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1958,
#             "name": "TRON",
#             "symbol": "TRX",
#             "slug": "tron",
#             "num_market_pairs": 488,
#             "date_added": "2017-09-13T00:00:00.000Z",
#             "tags": [
#                 "media",
#                 "payments",
#                 "tron-ecosystem",
#                 "binance-smart-chain"
#             ],
#             "max_supply": null,
#             "circulating_supply": 71659657369.49,
#             "total_supply": 100850743811.662,
#             "platform": null,
#             "cmc_rank": 26,
#             "last_updated": "2021-11-16T23:36:13.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.11039005208668541,
#                     "volume_24h": 3337174325.0789695,
#                     "volume_change_24h": -7.6864,
#                     "percent_change_1h": -1.08936893,
#                     "percent_change_24h": -10.84797883,
#                     "percent_change_7d": -3.1214385,
#                     "percent_change_30d": 12.03255707,
#                     "percent_change_60d": 4.89486477,
#                     "percent_change_90d": 29.0826159,
#                     "market_cap": 7910513309.532032,
#                     "market_cap_dominance": 0.3007,
#                     "fully_diluted_market_cap": 11132918862.35,
#                     "last_updated": "2021-11-16T23:36:13.000Z"
#                 }
#             }
#         },
#         {
#             "id": 8916,
#             "name": "Internet Computer",
#             "symbol": "ICP",
#             "slug": "internet-computer",
#             "num_market_pairs": 81,
#             "date_added": "2021-03-23T00:00:00.000Z",
#             "tags": [
#                 "platform",
#                 "distributed-computing",
#                 "polychain-capital-portfolio",
#                 "exnetwork-capital-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 182278418.45,
#             "total_supply": 474739504.27735364,
#             "platform": null,
#             "cmc_rank": 27,
#             "last_updated": "2021-11-16T23:37:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 43.046988128433284,
#                     "volume_24h": 487835846.2659159,
#                     "volume_change_24h": 85.6141,
#                     "percent_change_1h": -0.78547706,
#                     "percent_change_24h": -8.63796828,
#                     "percent_change_7d": -18.02317506,
#                     "percent_change_30d": -1.33137632,
#                     "percent_change_60d": -23.27270646,
#                     "percent_change_90d": -28.38431416,
#                     "market_cap": 7846536915.086744,
#                     "market_cap_dominance": 0.2987,
#                     "fully_diluted_market_cap": 20436105804.73,
#                     "last_updated": "2021-11-16T23:37:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2280,
#             "name": "Filecoin",
#             "symbol": "FIL",
#             "slug": "filecoin",
#             "num_market_pairs": 153,
#             "date_added": "2017-12-13T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "distributed-computing",
#                 "filesharing",
#                 "storage",
#                 "binance-smart-chain",
#                 "polychain-capital-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
#                 "dcg-portfolio",
#                 "hashkey-capital-portfolio",
#                 "a16z-portfolio",
#                 "winklevoss-capital-portfolio",
#                 "pantera-capital-portfolio"
#             ],
#             "max_supply": null,
#             "circulating_supply": 123491939,
#             "total_supply": 123491939,
#             "platform": null,
#             "cmc_rank": 28,
#             "last_updated": "2021-11-16T23:37:05.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 56.63147856775946,
#                     "volume_24h": 1415423669.4266698,
#                     "volume_change_24h": 207.6187,
# ...
#             "symbol": "BADGER",
#             "slug": "badger-dao",
#             "num_market_pairs": 55,
#             "date_added": "2020-12-04T00:00:00.000Z",
#             "tags": [
#                 "defi",
#                 "dao",
#                 "yield-farming",
#                 "yield-aggregator",
#                 "governance",
#                 "blockchain-capital-portfolio"
#             ],
#             "max_supply": 21000000,
#             "circulating_supply": 10285848.59854227,
#             "total_supply": 21000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0x3472a5a71965499acd81997a54bba8d852c6e53d"
#             },
#             "cmc_rank": 191,
#             "last_updated": "2021-11-16T23:36:08.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 28.334259168220584,
#                     "volume_24h": 29159027.99333766,
#                     "volume_change_24h": 43.0025,
#                     "percent_change_1h": -0.8702364,
#                     "percent_change_24h": -12.80855661,
#                     "percent_change_7d": -18.12766713,
#                     "percent_change_30d": 4.78344612,
#                     "percent_change_60d": 22.47214728,
#                     "percent_change_90d": 24.28410601,
#                     "market_cap": 291441899.95617515,
#                     "market_cap_dominance": 0.0111,
#                     "fully_diluted_market_cap": 595019442.53,
#                     "last_updated": "2021-11-16T23:36:08.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5268,
#             "name": "Energy Web Token",
#             "symbol": "EWT",
#             "slug": "energy-web-token",
#             "num_market_pairs": 18,
#             "date_added": "2020-03-28T00:00:00.000Z",
#             "tags": [
#                 "energy",
#                 "enterprise-solutions",
#                 "identity",
#                 "substrate",
#                 "polkadot-ecosystem"
#             ],
#             "max_supply": 100000000,
#             "circulating_supply": 30062138,
#             "total_supply": 48638535.4433,
#             "platform": null,
#             "cmc_rank": 192,
#             "last_updated": "2021-11-16T23:37:04.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 9.659792609869166,
#                     "volume_24h": 6131834.00109025,
#                     "volume_change_24h": -22.0389,
#                     "percent_change_1h": -0.61067433,
#                     "percent_change_24h": -7.09547563,
#                     "percent_change_7d": -1.48256956,
#                     "percent_change_30d": -15.23440518,
#                     "percent_change_60d": -7.53867076,
#                     "percent_change_90d": -7.89028298,
#                     "market_cap": 290394018.48926705,
#                     "market_cap_dominance": 0.0111,
#                     "fully_diluted_market_cap": 965979260.99,
#                     "last_updated": "2021-11-16T23:37:04.000Z"
#                 }
#             }
#         },
#         {
#             "id": 1762,
#             "name": "Ergo",
#             "symbol": "ERG",
#             "slug": "ergo",
#             "num_market_pairs": 17,
#             "date_added": "2017-06-29T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "platform",
#                 "dapp"
#             ],
#             "max_supply": 97739924,
#             "circulating_supply": 32012428,
#             "total_supply": 35316150,
#             "platform": null,
#             "cmc_rank": 193,
#             "last_updated": "2021-11-16T23:36:10.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 8.905801607676574,
#                     "volume_24h": 4971497.88097049,
#                     "volume_change_24h": 37.9398,
#                     "percent_change_1h": -0.42897943,
#                     "percent_change_24h": -3.60729206,
#                     "percent_change_7d": -12.9225833,
#                     "percent_change_30d": -12.83867349,
#                     "percent_change_60d": -49.11010018,
#                     "percent_change_90d": -22.98146258,
#                     "market_cap": 285096332.7480306,
#                     "market_cap_dominance": 0.0109,
#                     "fully_diluted_market_cap": 870452372.29,
#                     "last_updated": "2021-11-16T23:36:10.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4120,
#             "name": "Prometeus",
#             "symbol": "PROM",
#             "slug": "prometeus",
#             "num_market_pairs": 20,
#             "date_added": "2019-07-17T00:00:00.000Z",
#             "tags": [
#                 "binance-chain",
#                 "binance-smart-chain"
#             ],
#             "max_supply": null,
#             "circulating_supply": 16450000,
#             "total_supply": 19250000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xfc82bb4ba86045af6f327323a46e80412b91b27d"
#             },
#             "cmc_rank": 194,
#             "last_updated": "2021-11-16T23:37:02.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 17.158176976401926,
#                     "volume_24h": 18718041.63132404,
#                     "volume_change_24h": 87.8599,
#                     "percent_change_1h": 0.52547982,
#                     "percent_change_24h": -5.64181422,
#                     "percent_change_7d": -8.43575493,
#                     "percent_change_30d": -10.52658808,
#                     "percent_change_60d": -6.75123787,
#                     "percent_change_90d": -12.7655938,
#                     "market_cap": 282252011.2618117,
#                     "market_cap_dominance": 0.0107,
#                     "fully_diluted_market_cap": 330294906.8,
#                     "last_updated": "2021-11-16T23:37:02.000Z"
#                 }
#             }
#         },
#         {
#             "id": 541,
#             "name": "Syscoin",
#             "symbol": "SYS",
#             "slug": "syscoin",
#             "num_market_pairs": 21,
#             "date_added": "2014-08-20T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "platform",
#                 "enterprise-solutions",
#                 "collectibles-nfts",
#                 "masternodes",
#                 "scaling"
#             ],
#             "max_supply": 888000000,
#             "circulating_supply": 622528878.4159037,
#             "total_supply": 622528878.4159037,
#             "platform": null,
#             "cmc_rank": 195,
#             "last_updated": "2021-11-16T23:37:07.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.44525847300884325,
#                     "volume_24h": 29796931.55857525,
#                     "volume_change_24h": -60.8535,
#                     "percent_change_1h": -0.9455562,
#                     "percent_change_24h": -12.39490385,
#                     "percent_change_7d": 10.40538457,
#                     "percent_change_30d": -5.9345215,
#                     "percent_change_60d": 68.54903806,
#                     "percent_change_90d": 143.28197192,
#                     "market_cap": 277186257.8073731,
#                     "market_cap_dominance": 0.0105,
#                     "fully_diluted_market_cap": 395389524.03,
#                     "last_updated": "2021-11-16T23:37:07.000Z"
#                 }
#             }
#         },
#         {
#             "id": 4679,
#             "name": "Band Protocol",
#             "symbol": "BAND",
#             "slug": "band-protocol",
#             "num_market_pairs": 132,
#             "date_added": "2019-09-18T00:00:00.000Z",
#             "tags": [
#                 "cosmos-ecosystem",
#                 "defi",
#                 "oracles",
#                 "binance-chain",
#                 "binance-smart-chain",
#                 "binance-launchpad",
#                 "binance-labs-portfolio",
#                 "solana-ecosystem",
#                 "polygon-ecosystem",
#                 "fantom-ecosystem",
#                 "near-protocol-ecosystem"
#             ],
#             "max_supply": null,
#             "circulating_supply": 35191821,
#             "total_supply": 100000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xba11d00c5f74255f56a5e366f4f77f5a186d7f55"
#             },
#             "cmc_rank": 196,
#             "last_updated": "2021-11-16T23:37:07.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 7.8595508414011475,
#                     "volume_24h": 78446371.46290947,
#                     "volume_change_24h": 33.366,
#                     "percent_change_1h": -1.156222,
#                     "percent_change_24h": -9.7769463,
#                     "percent_change_7d": -15.06173278,
#                     "percent_change_30d": -6.11563192,
#                     "percent_change_60d": -13.20273254,
#                     "percent_change_90d": 1.22887977,
#                     "market_cap": 276591906.35098857,
#                     "market_cap_dominance": 0.0105,
#                     "fully_diluted_market_cap": 785955084.14,
#                     "last_updated": "2021-11-16T23:37:07.000Z"
#                 }
#             }
#         },
#         {
#             "id": 3835,
#             "name": "Orbs",
#             "symbol": "ORBS",
#             "slug": "orbs",
#             "num_market_pairs": 26,
#             "date_added": "2019-04-03T00:00:00.000Z",
#             "tags": [
#                 "services",
#                 "enterprise-solutions"
#             ],
#             "max_supply": null,
#             "circulating_supply": 2229950518.201359,
#             "total_supply": 10000000000,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xff56cc6b1e6ded347aa0b7676c85ab0b3d08b0fa"
#             },
#             "cmc_rank": 197,
#             "last_updated": "2021-11-16T23:36:10.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.12300003919035281,
#                     "volume_24h": 25262479.12222801,
#                     "volume_change_24h": 31.4568,
#                     "percent_change_1h": -0.75963884,
#                     "percent_change_24h": -5.79473771,
#                     "percent_change_7d": -2.5053027,
#                     "percent_change_30d": 4.18620588,
#                     "percent_change_60d": -14.90727199,
#                     "percent_change_90d": 31.10002713,
#                     "market_cap": 274284001.1313147,
#                     "market_cap_dominance": 0.0104,
#                     "fully_diluted_market_cap": 1230000391.9,
#                     "last_updated": "2021-11-16T23:36:10.000Z"
#                 }
#             }
#         },
#         {
#             "id": 5350,
#             "name": "Proton",
#             "symbol": "XPR",
#             "slug": "proton",
#             "num_market_pairs": 13,
#             "date_added": "2020-04-06T00:00:00.000Z",
#             "tags": [
#                 "collectibles-nfts",
#                 "decentralized-exchange",
#                 "defi",
#                 "wallet",
#                 "amm",
#                 "binance-smart-chain",
#                 "dex",
#                 "governance"
#             ],
#             "max_supply": null,
#             "circulating_supply": 8415884045.241,
#             "total_supply": 12282973173.105,
#             "platform": {
#                 "id": 1027,
#                 "name": "Ethereum",
#                 "symbol": "ETH",
#                 "slug": "ethereum",
#                 "token_address": "0xd7efb00d12c2c13131fd319336fdf952525da2af"
#             },
#             "cmc_rank": 199,
#             "last_updated": "2021-11-16T23:37:04.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.03210441037763967,
#                     "volume_24h": 14638623.71866329,
#                     "volume_change_24h": -7.3418,
#                     "percent_change_1h": 0.77110132,
#                     "percent_change_24h": -7.49274129,
#                     "percent_change_7d": -2.51540808,
#                     "percent_change_30d": -24.41010111,
#                     "percent_change_60d": 296.26415762,
#                     "percent_change_90d": 659.82028091,
#                     "market_cap": 270186995.07904726,
#                     "market_cap_dominance": 0.0103,
#                     "fully_diluted_market_cap": 394337611.41,
#                     "last_updated": "2021-11-16T23:37:04.000Z"
#                 }
#             }
#         },
#         {
#             "id": 2868,
#             "name": "Constellation",
#             "symbol": "DAG",
#             "slug": "constellation",
#             "num_market_pairs": 8,
#             "date_added": "2018-06-20T00:00:00.000Z",
#             "tags": [
#                 "dag",
#                 "platform",
#                 "payments",
#                 "smart-contracts"
#             ],
#             "max_supply": 3693588685,
#             "circulating_supply": 1266911931.0440834,
#             "total_supply": 3711998690.36,
#             "platform": null,
#             "cmc_rank": 198,
#             "last_updated": "2021-11-16T23:36:12.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 0.2126370106580842,
#                     "volume_24h": 4660749.9480878,
#                     "volume_change_24h": -8.6814,
#                     "percent_change_1h": -0.10536731,
#                     "percent_change_24h": -10.99095238,
#                     "percent_change_7d": -10.50616638,
#                     "percent_change_30d": 3.46692234,
#                     "percent_change_60d": -21.65718728,
#                     "percent_change_90d": -23.47799902,
#                     "market_cap": 269392365.7842748,
#                     "market_cap_dominance": 0.0102,
#                     "fully_diluted_market_cap": 785393656.58,
#                     "last_updated": "2021-11-16T23:36:12.000Z"
#                 }
#             }
#         },
#         {
#             "id": 7288,
#             "name": "Venus",
#             "symbol": "XVS",
#             "slug": "venus",
#             "num_market_pairs": 54,
#             "date_added": "2020-10-05T00:00:00.000Z",
#             "tags": [
#                 "defi",
#                 "yield-farming",
#                 "binance-smart-chain",
#                 "binance-launchpool",
#                 "lending-borowing"
#             ],
#             "max_supply": 29960733,
#             "circulating_supply": 11484806,
#             "total_supply": 29960733,
#             "platform": {
#                 "id": 1839,
#                 "name": "Binance Smart Chain (BEP20)",
#                 "symbol": "BNB",
#                 "slug": "binance-coin",
#                 "token_address": "0xcf6bb5389c92bdda8a3747ddb454cb7a64626c63"
#             },
#             "cmc_rank": 200,
#             "last_updated": "2021-11-16T23:37:04.000Z",
#             "quote": {
#                 "USD": {
#                     "price": 23.202353713933785,
#                     "volume_24h": 35105134.52656644,
#                     "volume_change_24h": 69.1622,
#                     "percent_change_1h": -0.83839546,
#                     "percent_change_24h": -6.30489904,
#                     "percent_change_7d": -16.2389834,
#                     "percent_change_30d": -15.87430858,
#                     "percent_change_60d": -24.46335458,
#                     "percent_change_90d": -31.38919924,
#                     "market_cap": 266474531.14790902,
#                     "market_cap_dominance": 0.0101,
#                     "fully_diluted_market_cap": 695159524.59,
#                     "last_updated": "2021-11-16T23:37:04.000Z"
#                 }
#             }
#         }
#     ]
# }

# %%
symbols = data['data'][0].get("symbol")
symbols
# Out:
# 'BTC'

# %%
import pandas as pd
crypto_symbols = []

for row in data['data']:
    crypto_symbols.append(pd.Series(row))
crypto_symbols
# Out:
# [id                                                                    1
#  name                                                            Bitcoin
#  symbol                                                              BTC
#  slug                                                            bitcoin
#  num_market_pairs                                                   8313
#  date_added                                     2013-04-28T00:00:00.000Z
#  tags                  [mineable, pow, sha-256, store-of-value, state...
#  max_supply                                                     21000000
#  circulating_supply                                             18875262
#  total_supply                                                   18875262
#  platform                                                           None
#  cmc_rank                                                              1
#  last_updated                                   2021-11-16T23:37:02.000Z
#  quote                 {'USD': {'price': 60387.99777535291, 'volume_2...
#  dtype: object,
#  id                                                                 1027
#  name                                                           Ethereum
#  symbol                                                              ETH
#  slug                                                           ethereum
#  num_market_pairs                                                   4646
#  date_added                                     2015-08-07T00:00:00.000Z
#  tags                  [mineable, pow, smart-contracts, ethereum-ecos...
#  max_supply                                                         None
#  circulating_supply                                        118369848.249
#  total_supply                                              118369848.249
#  platform                                                           None
#  cmc_rank                                                              2
#  last_updated                                   2021-11-16T23:37:02.000Z
#  quote                 {'USD': {'price': 4245.859785948198, 'volume_2...
#  dtype: object,
#  id                                                                 1839
#  name                                                       Binance Coin
#  symbol                                                              BNB
#  slug                                                       binance-coin
#  num_market_pairs                                                    554
#  date_added                                     2017-07-25T00:00:00.000Z
#  tags                  [marketplace, centralized-exchange, payments, ...
#  max_supply                                                    166801148
#  circulating_supply                                            166801148
#  total_supply                                                  166801148
#  platform                                                           None
#  cmc_rank                                                              3
#  last_updated                                   2021-11-16T23:36:08.000Z
#  quote                 {'USD': {'price': 590.2523596465625, 'volume_2...
#  dtype: object,
#  id                                                                  825
#  name                                                             Tether
#  symbol                                                             USDT
#  slug                                                             tether
#  num_market_pairs                                                  19337
#  date_added                                     2015-02-25T00:00:00.000Z
#  tags                  [payments, stablecoin, asset-backed-stablecoin...
#  max_supply                                                         None
#  circulating_supply                                   73761443730.021317
#  total_supply                                         76357051672.203644
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                              4
#  last_updated                                   2021-11-16T23:36:21.000Z
#  quote                 {'USD': {'price': 1.0005055889085632, 'volume_...
#  dtype: object,
#  id                                                                 5426
#  name                                                             Solana
#  symbol                                                              SOL
#  slug                                                             solana
#  num_market_pairs                                                    183
#  date_added                                     2020-04-10T00:00:00.000Z
#  tags                  [pos, platform, solana-ecosystem, cms-holdings...
#  max_supply                                                         None
#  circulating_supply                                     303467530.067583
#  total_supply                                           509195458.952264
#  platform                                                           None
#  cmc_rank                                                              5
#  last_updated                                   2021-11-16T23:37:05.000Z
#  quote                 {'USD': {'price': 221.00807872736777, 'volume_...
#  dtype: object,
#  id                                                                 2010
#  name                                                            Cardano
#  symbol                                                              ADA
#  slug                                                            cardano
#  num_market_pairs                                                    303
#  date_added                                     2017-10-01T00:00:00.000Z
#  tags                  [mineable, dpos, pos, platform, research, smar...
#  max_supply                                                  45000000000
#  circulating_supply                                      33313246914.729
#  total_supply                                            33719282563.077
#  platform                                                           None
#  cmc_rank                                                              6
#  last_updated                                   2021-11-16T23:36:21.000Z
#  quote                 {'USD': {'price': 1.889329408490415, 'volume_2...
#  dtype: object,
#  id                                                                   52
#  name                                                                XRP
#  symbol                                                              XRP
#  slug                                                                xrp
#  num_market_pairs                                                    628
#  date_added                                     2013-08-04T00:00:00.000Z
#  tags                  [medium-of-exchange, enterprise-solutions, bin...
#  max_supply                                                 100000000000
#  circulating_supply                                          47158974920
#  total_supply                                                99990145360
#  platform                                                           None
#  cmc_rank                                                              7
#  last_updated                                   2021-11-16T23:37:03.000Z
#  quote                 {'USD': {'price': 1.0976986700325273, 'volume_...
#  dtype: object,
#  id                                                                 6636
#  name                                                           Polkadot
#  symbol                                                              DOT
#  slug                                                       polkadot-new
#  num_market_pairs                                                    251
#  date_added                                     2020-08-19T00:00:00.000Z
#  tags                  [substrate, polkadot, binance-chain, binance-s...
#  max_supply                                                         None
#  circulating_supply                                     987579314.957085
#  total_supply                                          1103303471.382273
#  platform                                                           None
#  cmc_rank                                                              8
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 41.16642658103441, 'volume_2...
#  dtype: object,
#  id                                                                 3408
#  name                                                           USD Coin
#  symbol                                                             USDC
#  slug                                                           usd-coin
#  num_market_pairs                                                   1552
#  date_added                                     2018-10-08T00:00:00.000Z
#  tags                  [medium-of-exchange, stablecoin, asset-backed-...
#  max_supply                                                         None
#  circulating_supply                                   34424351583.842377
#  total_supply                                         34424351583.842377
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                              9
#  last_updated                                   2021-11-16T23:37:06.000Z
#  quote                 {'USD': {'price': 1.0000585050603574, 'volume_...
#  dtype: object,
#  id                                                                   74
#  name                                                           Dogecoin
#  symbol                                                             DOGE
#  slug                                                           dogecoin
#  num_market_pairs                                                    409
#  date_added                                     2013-12-15T00:00:00.000Z
#  tags                  [mineable, pow, scrypt, medium-of-exchange, me...
#  max_supply                                                         None
#  circulating_supply                                  132140677597.903488
#  total_supply                                        132140677597.903488
#  platform                                                           None
#  cmc_rank                                                             10
#  last_updated                                   2021-11-16T23:37:03.000Z
#  quote                 {'USD': {'price': 0.2386403755147686, 'volume_...
#  dtype: object,
#  id                                                                 5994
#  name                                                          SHIBA INU
#  symbol                                                             SHIB
#  slug                                                          shiba-inu
#  num_market_pairs                                                    160
#  date_added                                     2020-08-01T00:00:00.000Z
#  tags                                          [memes, doggone-doggerel]
#  max_supply                                                         None
#  circulating_supply                                      549095509738353
#  total_supply                                         589738956207003.75
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             11
#  last_updated                                   2021-11-16T23:36:21.000Z
#  quote                 {'USD': {'price': 4.8782538873173854e-05, 'vol...
#  dtype: object,
#  id                                                                 5805
#  name                                                          Avalanche
#  symbol                                                             AVAX
#  slug                                                          avalanche
#  num_market_pairs                                                    113
#  date_added                                     2020-07-13T00:00:00.000Z
#  tags                  [defi, smart-contracts, binance-smart-chain, p...
#  max_supply                                                    720000000
#  circulating_supply                                     220286577.207551
#  total_supply                                           391128418.867551
#  platform                                                           None
#  cmc_rank                                                             12
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 100.37169739936351, 'volume_...
#  dtype: object,
#  id                                                                 4172
#  name                                                              Terra
#  symbol                                                             LUNA
#  slug                                                         terra-luna
#  num_market_pairs                                                    104
#  date_added                                     2019-07-26T00:00:00.000Z
#  tags                  [cosmos-ecosystem, store-of-value, defi, payme...
#  max_supply                                                         None
#  circulating_supply                                     432071611.894612
#  total_supply                                           909122350.434096
#  platform                                                           None
#  cmc_rank                                                             13
#  last_updated                                   2021-11-16T23:37:03.000Z
#  quote                 {'USD': {'price': 43.58338393733085, 'volume_2...
#  dtype: object,
#  id                                                                    2
#  name                                                           Litecoin
#  symbol                                                              LTC
#  slug                                                           litecoin
#  num_market_pairs                                                    678
#  date_added                                     2013-04-28T00:00:00.000Z
#  tags                  [mineable, pow, scrypt, medium-of-exchange, bi...
#  max_supply                                                     84000000
#  circulating_supply                                      68988607.527125
#  total_supply                                                   84000000
#  platform                                                           None
#  cmc_rank                                                             14
#  last_updated                                   2021-11-16T23:37:02.000Z
#  quote                 {'USD': {'price': 232.19935613167, 'volume_24h...
#  dtype: object,
#  id                                                                 3717
#  name                                                    Wrapped Bitcoin
#  symbol                                                             WBTC
#  slug                                                    wrapped-bitcoin
#  num_market_pairs                                                    173
#  date_added                                     2019-01-30T00:00:00.000Z
#  tags                  [medium-of-exchange, defi, wrapped-tokens, fan...
#  max_supply                                                         None
#  circulating_supply                                        239132.081551
#  total_supply                                              239132.081551
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             15
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 59277.9648557776, 'volume_24...
#  dtype: object,
#  id                                                                 7083
#  name                                                            Uniswap
#  symbol                                                              UNI
#  slug                                                            uniswap
#  num_market_pairs                                                    285
#  date_added                                     2020-09-17T00:00:00.000Z
#  tags                  [decentralized-exchange, defi, dao, yield-farm...
#  max_supply                                                   1000000000
#  circulating_supply                                     627823666.772673
#  total_supply                                                 1000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             17
#  last_updated                                   2021-11-16T23:36:23.000Z
#  quote                 {'USD': {'price': 21.86446174751975, 'volume_2...
#  dtype: object,
#  id                                                                 1975
#  name                                                          Chainlink
#  symbol                                                             LINK
#  slug                                                          chainlink
#  num_market_pairs                                                    473
#  date_added                                     2017-09-20T00:00:00.000Z
#  tags                  [platform, defi, oracles, smart-contracts, sub...
#  max_supply                                                   1000000000
#  circulating_supply                                     465509553.917464
#  total_supply                                                 1000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             16
#  last_updated                                   2021-11-16T23:36:21.000Z
#  quote                 {'USD': {'price': 29.522186780860416, 'volume_...
#  dtype: object,
#  id                                                                 4687
#  name                                                        Binance USD
#  symbol                                                             BUSD
#  slug                                                        binance-usd
#  num_market_pairs                                                   1551
#  date_added                                     2019-09-20T00:00:00.000Z
#  tags                  [stablecoin, asset-backed-stablecoin, binance-...
#  max_supply                                                         None
#  circulating_supply                                   12873967472.639999
#  total_supply                                         12873967472.639999
#  platform              {'id': 1839, 'name': 'Binance Chain (BEP2)', '...
#  cmc_rank                                                             18
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 1.0000479833816909, 'volume_...
#  dtype: object,
#  id                                                                 1831
#  name                                                       Bitcoin Cash
#  symbol                                                              BCH
#  slug                                                       bitcoin-cash
#  num_market_pairs                                                    524
#  date_added                                     2017-07-23T00:00:00.000Z
#  tags                  [mineable, pow, sha-256, marketplace, medium-o...
#  max_supply                                                     21000000
#  circulating_supply                                          18902406.25
#  total_supply                                                18902406.25
#  platform                                                           None
#  cmc_rank                                                             19
#  last_updated                                   2021-11-16T23:36:16.000Z
#  quote                 {'USD': {'price': 603.700821796061, 'volume_24...
#  dtype: object,
#  id                                                                 3890
#  name                                                            Polygon
#  symbol                                                            MATIC
#  slug                                                            polygon
#  num_market_pairs                                                    253
#  date_added                                     2019-04-28T00:00:00.000Z
#  tags                  [platform, enterprise-solutions, state-channel...
#  max_supply                                                  10000000000
#  circulating_supply                                        6942890165.27
#  total_supply                                                10000000000
#  platform                                                           None
#  cmc_rank                                                             20
#  last_updated                                   2021-11-16T23:36:21.000Z
#  quote                 {'USD': {'price': 1.5762158899834646, 'volume_...
#  dtype: object,
#  id                                                                 4030
#  name                                                           Algorand
#  symbol                                                             ALGO
#  slug                                                           algorand
#  num_market_pairs                                                    157
#  date_added                                     2019-06-20T00:00:00.000Z
#  tags                  [pos, platform, research, smart-contracts, arr...
#  max_supply                                                  10000000000
#  circulating_supply                                    6250897203.072528
#  total_supply                                          6712630940.659888
#  platform                                                           None
#  cmc_rank                                                             21
#  last_updated                                   2021-11-16T23:36:20.000Z
#  quote                 {'USD': {'price': 1.7380179938925093, 'volume_...
#  dtype: object,
#  id                                                                 3635
#  name                                                    Crypto.com Coin
#  symbol                                                              CRO
#  slug                                                    crypto-com-coin
#  num_market_pairs                                                    110
#  date_added                                     2018-12-14T00:00:00.000Z
#  tags                  [medium-of-exchange, cosmos-ecosystem, central...
#  max_supply                                                  30263013692
#  circulating_supply                                          25263013692
#  total_supply                                                30263013692
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             22
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 0.41884253551897455, 'volume...
#  dtype: object,
#  id                                                                 3077
#  name                                                            VeChain
#  symbol                                                              VET
#  slug                                                            vechain
#  num_market_pairs                                                    149
#  date_added                                     2017-08-22T00:00:00.000Z
#  tags                  [logistics, data-provenance, iot, smart-contra...
#  max_supply                                                  86712634466
#  circulating_supply                                          64315576989
#  total_supply                                                86712634466
#  platform                                                           None
#  cmc_rank                                                             23
#  last_updated                                   2021-11-16T23:37:02.000Z
#  quote                 {'USD': {'price': 0.14632618331452413, 'volume...
#  dtype: object,
#  id                                                                  512
#  name                                                            Stellar
#  symbol                                                              XLM
#  slug                                                            stellar
#  num_market_pairs                                                    322
#  date_added                                     2014-08-05T00:00:00.000Z
#  tags                  [medium-of-exchange, enterprise-solutions, dec...
#  max_supply                                                  50001806812
#  circulating_supply                                   24286104252.359505
#  total_supply                                         50001802590.975151
#  platform                                                           None
#  cmc_rank                                                             24
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 0.34631917990218, 'volume_24...
#  dtype: object,
#  id                                                                 6783
#  name                                                      Axie Infinity
#  symbol                                                              AXS
#  slug                                                      axie-infinity
#  num_market_pairs                                                    133
#  date_added                                     2020-08-31T00:00:00.000Z
#  tags                  [collectibles-nfts, gaming, binance-launchpad,...
#  max_supply                                                    270000000
#  circulating_supply                                             60907500
#  total_supply                                                  270000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             25
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 135.06561341701422, 'volume_...
#  dtype: object,
#  id                                                                 1958
#  name                                                               TRON
#  symbol                                                              TRX
#  slug                                                               tron
#  num_market_pairs                                                    488
#  date_added                                     2017-09-13T00:00:00.000Z
#  tags                  [media, payments, tron-ecosystem, binance-smar...
#  max_supply                                                         None
#  circulating_supply                                   71659657369.490005
#  total_supply                                        100850743811.662003
#  platform                                                           None
#  cmc_rank                                                             26
#  last_updated                                   2021-11-16T23:36:13.000Z
#  quote                 {'USD': {'price': 0.11039005208668541, 'volume...
#  dtype: object,
#  id                                                                 8916
#  name                                                  Internet Computer
#  symbol                                                              ICP
#  slug                                                  internet-computer
#  num_market_pairs                                                     81
#  date_added                                     2021-03-23T00:00:00.000Z
#  tags                  [platform, distributed-computing, polychain-ca...
#  max_supply                                                         None
#  circulating_supply                                         182278418.45
#  total_supply                                           474739504.277354
#  platform                                                           None
#  cmc_rank                                                             27
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 43.046988128433284, 'volume_...
#  dtype: object,
#  id                                                                 2280
#  name                                                           Filecoin
#  symbol                                                              FIL
#  slug                                                           filecoin
#  num_market_pairs                                                    153
#  date_added                                     2017-12-13T00:00:00.000Z
#  tags                  [mineable, distributed-computing, filesharing,...
#  max_supply                                                         None
#  circulating_supply                                            123491939
#  total_supply                                                  123491939
#  platform                                                           None
#  cmc_rank                                                             28
#  last_updated                                   2021-11-16T23:37:05.000Z
#  quote                 {'USD': {'price': 56.63147856775946, 'volume_2...
#  dtype: object,
#  id                                                                 1321
#  name                                                   Ethereum Classic
#  symbol                                                              ETC
#  slug                                                   ethereum-classic
#  num_market_pairs                                                    256
#  date_added                                     2016-07-24T00:00:00.000Z
#  tags                  [mineable, pow, ethash, platform, smart-contra...
#  max_supply                                                    210700000
#  circulating_supply                                      131033767.67763
#  total_supply                                                  210700000
#  platform                                                           None
#  cmc_rank                                                             29
#  last_updated                                   2021-11-16T23:37:05.000Z
#  quote                 {'USD': {'price': 51.27639656285722, 'volume_2...
#  dtype: object,
#  id                                                                 4943
#  name                                                                Dai
#  symbol                                                              DAI
#  slug                                               multi-collateral-dai
#  num_market_pairs                                                    426
#  date_added                                     2019-11-22T00:00:00.000Z
#  tags                  [defi, stablecoin, ethereum-ecosystem, binance...
#  max_supply                                                         None
#  circulating_supply                                    6474951713.635377
#  total_supply                                          6474952202.474523
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             30
#  last_updated                                   2021-11-16T23:36:21.000Z
#  quote                 {'USD': {'price': 1.0014590384530595, 'volume_...
#  dtype: object,
#  id                                                                 3794
#  name                                                             Cosmos
#  symbol                                                             ATOM
#  slug                                                             cosmos
#  num_market_pairs                                                    188
#  date_added                                     2019-03-14T00:00:00.000Z
#  tags                  [platform, cosmos-ecosystem, content-creation,...
#  max_supply                                                         None
#  circulating_supply                                     224673556.034991
#  total_supply                                           282458159.034991
#  platform                                                           None
#  cmc_rank                                                             31
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 28.66085575387923, 'volume_2...
#  dtype: object,
#  id                                                                 4023
#  name                                                       Bitcoin BEP2
#  symbol                                                             BTCB
#  slug                                                       bitcoin-bep2
#  num_market_pairs                                                     61
#  date_added                                     2019-06-18T00:00:00.000Z
#  tags                               [binance-chain, binance-smart-chain]
#  max_supply                                                         None
#  circulating_supply                                        105112.768434
#  total_supply                                                     112501
#  platform              {'id': 1839, 'name': 'Binance Chain (BEP2)', '...
#  cmc_rank                                                             32
#  last_updated                                   2021-11-16T23:36:23.000Z
#  quote                 {'USD': {'price': 60478.28737750943, 'volume_2...
#  dtype: object,
#  id                                                                 2416
#  name                                                              THETA
#  symbol                                                            THETA
#  slug                                                              theta
#  num_market_pairs                                                     80
#  date_added                                     2018-01-17T00:00:00.000Z
#  tags                  [media, collectibles-nfts, content-creation, v...
#  max_supply                                                   1000000000
#  circulating_supply                                           1000000000
#  total_supply                                                 1000000000
#  platform                                                           None
#  cmc_rank                                                             33
#  last_updated                                   2021-11-16T23:37:06.000Z
#  quote                 {'USD': {'price': 6.321319938293855, 'volume_2...
#  dtype: object,
#  id                                                                 4195
#  name                                                          FTX Token
#  symbol                                                              FTT
#  slug                                                          ftx-token
#  num_market_pairs                                                     88
#  date_added                                     2019-07-31T00:00:00.000Z
#  tags                  [marketplace, centralized-exchange, derivative...
#  max_supply                                                    352170015
#  circulating_supply                                     120014732.218744
#  total_supply                                           335885068.285972
#  platform              {'id': 1839, 'name': 'Binance Chain (BEP2)', '...
#  cmc_rank                                                             34
#  last_updated                                   2021-11-16T23:37:03.000Z
#  quote                 {'USD': {'price': 50.63763597310524, 'volume_2...
#  dtype: object,
#  id                                                                 4642
#  name                                                             Hedera
#  symbol                                                             HBAR
#  slug                                                             hedera
#  num_market_pairs                                                     70
#  date_added                                     2019-09-17T00:00:00.000Z
#  tags                  [dag, marketplace, enterprise-solutions, payme...
#  max_supply                                                  50000000000
#  circulating_supply                                    15018941582.14876
#  total_supply                                                50000000000
#  platform                                                           None
#  cmc_rank                                                             35
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 0.401445325361483, 'volume_2...
#  dtype: object,
#  id                                                                 6892
#  name                                                             Elrond
#  symbol                                                             EGLD
#  slug                                                        elrond-egld
#  num_market_pairs                                                     59
#  date_added                                     2020-09-04T00:00:00.000Z
#  tags                  [binance-smart-chain, binance-launchpad, binan...
#  max_supply                                                     31415926
#  circulating_supply                                        19745414.1438
#  total_supply                                                   22738134
#  platform                                                           None
#  cmc_rank                                                             36
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 304.94795554611454, 'volume_...
#  dtype: object,
#  id                                                                 1966
#  name                                                       Decentraland
#  symbol                                                             MANA
#  slug                                                       decentraland
#  num_market_pairs                                                    188
#  date_added                                     2017-09-17T00:00:00.000Z
#  tags                  [platform, collectibles-nfts, gaming, payments...
#  max_supply                                                         None
#  circulating_supply                                    1816919591.495089
#  total_supply                                          2193999827.320146
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             37
#  last_updated                                   2021-11-16T23:36:22.000Z
#  quote                 {'USD': {'price': 3.291753168652648, 'volume_2...
#  dtype: object,
#  id                                                                 7129
#  name                                                           TerraUSD
#  symbol                                                              UST
#  slug                                                           terrausd
#  num_market_pairs                                                    108
#  date_added                                     2020-09-21T00:00:00.000Z
#  tags                  [stablecoin, binance-smart-chain, terra-ecosys...
#  max_supply                                                         None
#  circulating_supply                                    5786396170.708132
#  total_supply                                          5786396170.708132
#  platform                                                           None
#  cmc_rank                                                             38
#  last_updated                                   2021-11-16T23:36:23.000Z
#  quote                 {'USD': {'price': 1.0037906253542477, 'volume_...
#  dtype: object,
#  id                                                                 3513
#  name                                                             Fantom
#  symbol                                                              FTM
#  slug                                                             fantom
#  num_market_pairs                                                    119
#  date_added                                     2018-10-29T00:00:00.000Z
#  tags                  [platform, enterprise-solutions, defi, researc...
#  max_supply                                                   3175000000
#  circulating_supply                                           2545006273
#  total_supply                                                 2545006273
#  platform                                                           None
#  cmc_rank                                                             39
#  last_updated                                   2021-11-16T23:37:06.000Z
#  quote                 {'USD': {'price': 2.2248795972707183, 'volume_...
#  dtype: object,
#  id                                                                 6535
#  name                                                      NEAR Protocol
#  symbol                                                             NEAR
#  slug                                                      near-protocol
#  num_market_pairs                                                     71
#  date_added                                     2020-08-11T00:00:00.000Z
#  tags                  [platform, staking, binance-smart-chain, coinb...
#  max_supply                                                   1000000000
#  circulating_supply                                            547445154
#  total_supply                                                 1000000000
#  platform                                                           None
#  cmc_rank                                                             40
#  last_updated                                   2021-11-16T23:37:06.000Z
#  quote                 {'USD': {'price': 9.787454935828956, 'volume_2...
#  dtype: object,
#  id                                                                 2011
#  name                                                              Tezos
#  symbol                                                              XTZ
#  slug                                                              tezos
#  num_market_pairs                                                    175
#  date_added                                     2017-10-06T00:00:00.000Z
#  tags                  [pos, platform, enterprise-solutions, collecti...
#  max_supply                                                         None
#  circulating_supply                                     867183651.474138
#  total_supply                                           896023485.122089
#  platform                                                           None
#  cmc_rank                                                             41
#  last_updated                                   2021-11-16T23:36:23.000Z
#  quote                 {'USD': {'price': 5.274954892914704, 'volume_2...
#  dtype: object,
#  id                                                                 5665
#  name                                                             Helium
#  symbol                                                              HNT
#  slug                                                             helium
#  num_market_pairs                                                     31
#  date_added                                     2020-06-05T00:00:00.000Z
#  tags                  [mineable, enterprise-solutions, distributed-c...
#  max_supply                                                    223000000
#  circulating_supply                                     102104046.327457
#  total_supply                                                  223000000
#  platform                                                           None
#  cmc_rank                                                             42
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 44.71414507871443, 'volume_2...
#  dtype: object,
#  id                                                                 6719
#  name                                                          The Graph
#  symbol                                                              GRT
#  slug                                                          the-graph
#  num_market_pairs                                                    136
#  date_added                                     2020-12-17T00:00:00.000Z
#  tags                  [ai-big-data, enterprise-solutions, defi, bina...
#  max_supply                                                  10057044431
#  circulating_supply                                           4715735200
#  total_supply                                                10000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             43
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 0.9315901559948458, 'volume_...
#  dtype: object,
#  id                                                                  328
#  name                                                             Monero
#  symbol                                                              XMR
#  slug                                                             monero
#  num_market_pairs                                                    148
#  date_added                                     2014-05-21T00:00:00.000Z
#  tags                  [mineable, pow, medium-of-exchange, privacy, r...
#  max_supply                                                         None
#  circulating_supply                                      18014103.584424
#  total_supply                                            18014103.584424
#  platform                                                           None
#  cmc_rank                                                             44
#  last_updated                                   2021-11-16T23:37:05.000Z
#  quote                 {'USD': {'price': 242.9601502658086, 'volume_2...
#  dtype: object,
#  id                                                                 1765
#  name                                                                EOS
#  symbol                                                              EOS
#  slug                                                                eos
#  num_market_pairs                                                    382
#  date_added                                     2017-07-01T00:00:00.000Z
#  tags                  [medium-of-exchange, enterprise-solutions, sma...
#  max_supply                                                         None
#  circulating_supply                                       971470658.2698
#  total_supply                                            1039471070.1525
#  platform                                                           None
#  cmc_rank                                                             45
#  last_updated                                   2021-11-16T23:36:08.000Z
#  quote                 {'USD': {'price': 4.3636706716403095, 'volume_...
#  dtype: object,
#  id                                                                 7186
#  name                                                        PancakeSwap
#  symbol                                                             CAKE
#  slug                                                        pancakeswap
#  num_market_pairs                                                    136
#  date_added                                     2020-09-25T00:00:00.000Z
#  tags                  [decentralized-exchange, defi, yield-farming, ...
#  max_supply                                                         None
#  circulating_supply                                     241564212.551432
#  total_supply                                           241564212.551432
#  platform              {'id': 1839, 'name': 'Binance Smart Chain (BEP...
#  cmc_rank                                                             46
#  last_updated                                   2021-11-16T23:37:03.000Z
#  quote                 {'USD': {'price': 16.960409805028032, 'volume_...
#  dtype: object,
#  id                                                                 4558
#  name                                                               Flow
#  symbol                                                             FLOW
# ...
#  total_supply                                           879999999.986466
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            185
#  last_updated                                   2021-11-16T23:37:04.000Z
#  quote                 {'USD': {'price': 0.5568975170503505, 'volume_...
#  dtype: object,
#  id                                                                 2758
#  name                                                          Unibright
#  symbol                                                              UBT
#  slug                                                          unibright
#  num_market_pairs                                                     19
#  date_added                                     2018-05-21T00:00:00.000Z
#  tags                                                                 []
#  max_supply                                                    150000000
#  circulating_supply                                     149999999.243493
#  total_supply                                                  150000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            186
#  last_updated                                   2021-11-16T23:36:08.000Z
#  quote                 {'USD': {'price': 1.9918605140148948, 'volume_...
#  dtype: object,
#  id                                                                 8766
#  name                                                    MyNeighborAlice
#  symbol                                                            ALICE
#  slug                                                    myneighboralice
#  num_market_pairs                                                     66
#  date_added                                     2021-03-10T00:00:00.000Z
#  tags                  [collectibles-nfts, gaming, entertainment, met...
#  max_supply                                                    100000000
#  circulating_supply                                             23000000
#  total_supply                                                  100000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            187
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 12.917518300576388, 'volume_...
#  dtype: object,
#  id                                                                 3673
#  name                                                                ASD
#  symbol                                                              ASD
#  slug                                                       bitmax-token
#  num_market_pairs                                                      7
#  date_added                                     2019-01-08T00:00:00.000Z
#  tags                                             [centralized-exchange]
#  max_supply                                                         None
#  circulating_supply                                            660615274
#  total_supply                                                  780615274
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            188
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 0.44902020875047544, 'volume...
#  dtype: object,
#  id                                                                 2297
#  name                                                             StormX
#  symbol                                                             STMX
#  slug                                                             stormx
#  num_market_pairs                                                     31
#  date_added                                     2017-12-20T00:00:00.000Z
#  tags                                                   [media, loyalty]
#  max_supply                                                  10000000000
#  circulating_supply                                          10000000000
#  total_supply                                                10000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            189
#  last_updated                                   2021-11-16T23:37:05.000Z
#  quote                 {'USD': {'price': 0.029404279921241717, 'volum...
#  dtype: object,
#  id                                                                 3816
#  name                                                           Verasity
#  symbol                                                              VRA
#  slug                                                           verasity
#  num_market_pairs                                                     32
#  date_added                                     2019-04-03T00:00:00.000Z
#  tags                  [collectibles-nfts, gaming, entertainment, pay...
#  max_supply                                                  10356466695
#  circulating_supply                                    4470185345.808827
#  total_supply                                         19400882350.003914
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            190
#  last_updated                                   2021-11-16T23:37:08.000Z
#  quote                 {'USD': {'price': 0.06536340257630176, 'volume...
#  dtype: object,
#  id                                                                 7859
#  name                                                         Badger DAO
#  symbol                                                           BADGER
#  slug                                                         badger-dao
#  num_market_pairs                                                     55
#  date_added                                     2020-12-04T00:00:00.000Z
#  tags                  [defi, dao, yield-farming, yield-aggregator, g...
#  max_supply                                                     21000000
#  circulating_supply                                      10285848.598542
#  total_supply                                                   21000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            191
#  last_updated                                   2021-11-16T23:36:08.000Z
#  quote                 {'USD': {'price': 28.334259168220584, 'volume_...
#  dtype: object,
#  id                                                                 5268
#  name                                                   Energy Web Token
#  symbol                                                              EWT
#  slug                                                   energy-web-token
#  num_market_pairs                                                     18
#  date_added                                     2020-03-28T00:00:00.000Z
#  tags                  [energy, enterprise-solutions, identity, subst...
#  max_supply                                                    100000000
#  circulating_supply                                             30062138
#  total_supply                                              48638535.4433
#  platform                                                           None
#  cmc_rank                                                            192
#  last_updated                                   2021-11-16T23:37:04.000Z
#  quote                 {'USD': {'price': 9.659792609869166, 'volume_2...
#  dtype: object,
#  id                                                                 1762
#  name                                                               Ergo
#  symbol                                                              ERG
#  slug                                                               ergo
#  num_market_pairs                                                     17
#  date_added                                     2017-06-29T00:00:00.000Z
#  tags                                    [mineable, pow, platform, dapp]
#  max_supply                                                     97739924
#  circulating_supply                                             32012428
#  total_supply                                                   35316150
#  platform                                                           None
#  cmc_rank                                                            193
#  last_updated                                   2021-11-16T23:36:10.000Z
#  quote                 {'USD': {'price': 8.905801607676574, 'volume_2...
#  dtype: object,
#  id                                                                 4120
#  name                                                          Prometeus
#  symbol                                                             PROM
#  slug                                                          prometeus
#  num_market_pairs                                                     20
#  date_added                                     2019-07-17T00:00:00.000Z
#  tags                               [binance-chain, binance-smart-chain]
#  max_supply                                                         None
#  circulating_supply                                             16450000
#  total_supply                                                   19250000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            194
#  last_updated                                   2021-11-16T23:37:02.000Z
#  quote                 {'USD': {'price': 17.158176976401926, 'volume_...
#  dtype: object,
#  id                                                                  541
#  name                                                            Syscoin
#  symbol                                                              SYS
#  slug                                                            syscoin
#  num_market_pairs                                                     21
#  date_added                                     2014-08-20T00:00:00.000Z
#  tags                  [mineable, pow, platform, enterprise-solutions...
#  max_supply                                                    888000000
#  circulating_supply                                     622528878.415904
#  total_supply                                           622528878.415904
#  platform                                                           None
#  cmc_rank                                                            195
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 0.44525847300884325, 'volume...
#  dtype: object,
#  id                                                                 4679
#  name                                                      Band Protocol
#  symbol                                                             BAND
#  slug                                                      band-protocol
#  num_market_pairs                                                    132
#  date_added                                     2019-09-18T00:00:00.000Z
#  tags                  [cosmos-ecosystem, defi, oracles, binance-chai...
#  max_supply                                                         None
#  circulating_supply                                             35191821
#  total_supply                                                  100000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            196
#  last_updated                                   2021-11-16T23:37:07.000Z
#  quote                 {'USD': {'price': 7.8595508414011475, 'volume_...
#  dtype: object,
#  id                                                                 3835
#  name                                                               Orbs
#  symbol                                                             ORBS
#  slug                                                               orbs
#  num_market_pairs                                                     26
#  date_added                                     2019-04-03T00:00:00.000Z
#  tags                                   [services, enterprise-solutions]
#  max_supply                                                         None
#  circulating_supply                                    2229950518.201359
#  total_supply                                                10000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            197
#  last_updated                                   2021-11-16T23:36:10.000Z
#  quote                 {'USD': {'price': 0.12300003919035281, 'volume...
#  dtype: object,
#  id                                                                 5350
#  name                                                             Proton
#  symbol                                                              XPR
#  slug                                                             proton
#  num_market_pairs                                                     13
#  date_added                                     2020-04-06T00:00:00.000Z
#  tags                  [collectibles-nfts, decentralized-exchange, de...
#  max_supply                                                         None
#  circulating_supply                                       8415884045.241
#  total_supply                                            12282973173.105
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            199
#  last_updated                                   2021-11-16T23:37:04.000Z
#  quote                 {'USD': {'price': 0.03210441037763967, 'volume...
#  dtype: object,
#  id                                                                 2868
#  name                                                      Constellation
#  symbol                                                              DAG
#  slug                                                      constellation
#  num_market_pairs                                                      8
#  date_added                                     2018-06-20T00:00:00.000Z
#  tags                         [dag, platform, payments, smart-contracts]
#  max_supply                                                   3693588685
#  circulating_supply                                    1266911931.044083
#  total_supply                                              3711998690.36
#  platform                                                           None
#  cmc_rank                                                            198
#  last_updated                                   2021-11-16T23:36:12.000Z
#  quote                 {'USD': {'price': 0.2126370106580842, 'volume_...
#  dtype: object,
#  id                                                                 7288
#  name                                                              Venus
#  symbol                                                              XVS
#  slug                                                              venus
#  num_market_pairs                                                     54
#  date_added                                     2020-10-05T00:00:00.000Z
#  tags                  [defi, yield-farming, binance-smart-chain, bin...
#  max_supply                                                     29960733
#  circulating_supply                                             11484806
#  total_supply                                                   29960733
#  platform              {'id': 1839, 'name': 'Binance Smart Chain (BEP...
#  cmc_rank                                                            200
#  last_updated                                   2021-11-16T23:37:04.000Z
#  quote                 {'USD': {'price': 23.202353713933785, 'volume_...
#  dtype: object]

# %%
crypto_df = pd.DataFrame(
    data = crypto_symbols
)
crypto_df = crypto_df["symbol"]
crypto_df
# Out:
# 0       BTC
# 1       ETH
# 2       BNB
# 3      USDT
# 4       SOL
#        ...
# 195    BAND
# 196    ORBS
# 197     XPR
# 198     DAG
# 199     XVS
# Name: symbol, Length: 200, dtype: object

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import pprint

listing_url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '16309f60-d6b0-492a-8596-06df4758b8c2',
}

session = Session()
session.headers.update(headers)

# try:
#   response = session.get(listing_url, params=parameters)
#   data = json.loads(response.text)
#   print(json.dumps(data, indent=4))
# except (ConnectionError, Timeout, TooManyRedirects) as e:
#   print(e)

# try:
#   response = session.get(quote_url, params=parameters)
#   data = json.loads(response.text)
#   print(json.dumps(data, indent=4))
# except (ConnectionError, Timeout, TooManyRedirects) as e:
#   print(e)

response = session.get(listing_url, params=parameters)

data = json.loads(response.text)
crypto = []
for row in data["data"]:
    crypto.append(pd.Series(row))
crypto
# Out:
# [id                                                                    1
#  name                                                            Bitcoin
#  symbol                                                              BTC
#  slug                                                            bitcoin
#  num_market_pairs                                                   8311
#  date_added                                     2013-04-28T00:00:00.000Z
#  tags                  [mineable, pow, sha-256, store-of-value, state...
#  max_supply                                                     21000000
#  circulating_supply                                             18877075
#  total_supply                                                   18877075
#  platform                                                           None
#  cmc_rank                                                              1
#  last_updated                                   2021-11-18T22:50:02.000Z
#  quote                 {'USD': {'price': 57025.27747501414, 'volume_2...
#  dtype: object,
#  id                                                                 1027
#  name                                                           Ethereum
#  symbol                                                              ETH
#  slug                                                           ethereum
#  num_market_pairs                                                   4656
#  date_added                                     2015-08-07T00:00:00.000Z
#  tags                  [mineable, pow, smart-contracts, ethereum-ecos...
#  max_supply                                                         None
#  circulating_supply                                       118396558.1865
#  total_supply                                             118396558.1865
#  platform                                                           None
#  cmc_rank                                                              2
#  last_updated                                   2021-11-18T22:50:02.000Z
#  quote                 {'USD': {'price': 3989.0948955060276, 'volume_...
#  dtype: object,
#  id                                                                 1839
#  name                                                       Binance Coin
#  symbol                                                              BNB
#  slug                                                       binance-coin
#  num_market_pairs                                                    557
#  date_added                                     2017-07-25T00:00:00.000Z
#  tags                  [marketplace, centralized-exchange, payments, ...
#  max_supply                                                    166801148
#  circulating_supply                                            166801148
#  total_supply                                                  166801148
#  platform                                                           None
#  cmc_rank                                                              3
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 530.9635999500547, 'volume_2...
#  dtype: object,
#  id                                                                  825
#  name                                                             Tether
#  symbol                                                             USDT
#  slug                                                             tether
#  num_market_pairs                                                  19767
#  date_added                                     2015-02-25T00:00:00.000Z
#  tags                  [payments, stablecoin, asset-backed-stablecoin...
#  max_supply                                                         None
#  circulating_supply                                   73761443730.021317
#  total_supply                                         76357051672.203644
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                              4
#  last_updated                                   2021-11-18T22:49:10.000Z
#  quote                 {'USD': {'price': 1.0014788682766893, 'volume_...
#  dtype: object,
#  id                                                                 2010
#  name                                                            Cardano
#  symbol                                                              ADA
#  slug                                                            cardano
#  num_market_pairs                                                    304
#  date_added                                     2017-10-01T00:00:00.000Z
#  tags                  [mineable, dpos, pos, platform, research, smar...
#  max_supply                                                  45000000000
#  circulating_supply                                      33313246914.729
#  total_supply                                            33719282563.077
#  platform                                                           None
#  cmc_rank                                                              5
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 1.7753835956614867, 'volume_...
#  dtype: object,
#  id                                                                 5426
#  name                                                             Solana
#  symbol                                                              SOL
#  slug                                                             solana
#  num_market_pairs                                                    185
#  date_added                                     2020-04-10T00:00:00.000Z
#  tags                  [pos, platform, solana-ecosystem, cms-holdings...
#  max_supply                                                         None
#  circulating_supply                                      303507025.08921
#  total_supply                                           509194266.568913
#  platform                                                           None
#  cmc_rank                                                              6
#  last_updated                                   2021-11-18T22:50:05.000Z
#  quote                 {'USD': {'price': 194.37702896160152, 'volume_...
#  dtype: object,
#  id                                                                   52
#  name                                                                XRP
#  symbol                                                              XRP
#  slug                                                                xrp
#  num_market_pairs                                                    630
#  date_added                                     2013-08-04T00:00:00.000Z
#  tags                  [medium-of-exchange, enterprise-solutions, bin...
#  max_supply                                                 100000000000
#  circulating_supply                                          47158974920
#  total_supply                                                99990145360
#  platform                                                           None
#  cmc_rank                                                              7
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 1.0447257689110354, 'volume_...
#  dtype: object,
#  id                                                                 6636
#  name                                                           Polkadot
#  symbol                                                              DOT
#  slug                                                       polkadot-new
#  num_market_pairs                                                    255
#  date_added                                     2020-08-19T00:00:00.000Z
#  tags                  [substrate, polkadot, binance-chain, binance-s...
#  max_supply                                                         None
#  circulating_supply                                     987579314.957085
#  total_supply                                          1103303471.382273
#  platform                                                           None
#  cmc_rank                                                              8
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 38.93013469866396, 'volume_2...
#  dtype: object,
#  id                                                                 3408
#  name                                                           USD Coin
#  symbol                                                             USDC
#  slug                                                           usd-coin
#  num_market_pairs                                                   1560
#  date_added                                     2018-10-08T00:00:00.000Z
#  tags                  [medium-of-exchange, stablecoin, asset-backed-...
#  max_supply                                                         None
#  circulating_supply                                   34424351583.842377
#  total_supply                                         34424351583.842377
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                              9
#  last_updated                                   2021-11-18T22:50:05.000Z
#  quote                 {'USD': {'price': 1.0012040747733617, 'volume_...
#  dtype: object,
#  id                                                                   74
#  name                                                           Dogecoin
#  symbol                                                             DOGE
#  slug                                                           dogecoin
#  num_market_pairs                                                    411
#  date_added                                     2013-12-15T00:00:00.000Z
#  tags                  [mineable, pow, scrypt, medium-of-exchange, me...
#  max_supply                                                         None
#  circulating_supply                                  132168039255.066589
#  total_supply                                        132168039255.066589
#  platform                                                           None
#  cmc_rank                                                             10
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 0.2211905887514358, 'volume_...
#  dtype: object,
#  id                                                                 5994
#  name                                                          SHIBA INU
#  symbol                                                             SHIB
#  slug                                                          shiba-inu
#  num_market_pairs                                                    161
#  date_added                                     2020-08-01T00:00:00.000Z
#  tags                                          [memes, doggone-doggerel]
#  max_supply                                                         None
#  circulating_supply                                 549055952729358.6875
#  total_supply                                          589737271202616.5
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             11
#  last_updated                                   2021-11-18T22:49:11.000Z
#  quote                 {'USD': {'price': 4.2127873816637366e-05, 'vol...
#  dtype: object,
#  id                                                                 5805
#  name                                                          Avalanche
#  symbol                                                             AVAX
#  slug                                                          avalanche
#  num_market_pairs                                                    116
#  date_added                                     2020-07-13T00:00:00.000Z
#  tags                  [defi, smart-contracts, binance-smart-chain, p...
#  max_supply                                                    720000000
#  circulating_supply                                     220286577.207551
#  total_supply                                           391128418.867551
#  platform                                                           None
#  cmc_rank                                                             12
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 98.5564315376257, 'volume_24...
#  dtype: object,
#  id                                                                 4172
#  name                                                              Terra
#  symbol                                                             LUNA
#  slug                                                         terra-luna
#  num_market_pairs                                                    105
#  date_added                                     2019-07-26T00:00:00.000Z
#  tags                  [cosmos-ecosystem, store-of-value, defi, payme...
#  max_supply                                                         None
#  circulating_supply                                     414886417.876625
#  total_supply                                           891837736.521225
#  platform                                                           None
#  cmc_rank                                                             13
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 40.392796981929095, 'volume_...
#  dtype: object,
#  id                                                                    2
#  name                                                           Litecoin
#  symbol                                                              LTC
#  slug                                                           litecoin
#  num_market_pairs                                                    681
#  date_added                                     2013-04-28T00:00:00.000Z
#  tags                  [mineable, pow, scrypt, medium-of-exchange, bi...
#  max_supply                                                     84000000
#  circulating_supply                                      69002882.459331
#  total_supply                                                   84000000
#  platform                                                           None
#  cmc_rank                                                             14
#  last_updated                                   2021-11-18T22:50:02.000Z
#  quote                 {'USD': {'price': 204.52766508770537, 'volume_...
#  dtype: object,
#  id                                                                 3717
#  name                                                    Wrapped Bitcoin
#  symbol                                                             WBTC
#  slug                                                    wrapped-bitcoin
#  num_market_pairs                                                    173
#  date_added                                     2019-01-30T00:00:00.000Z
#  tags                  [medium-of-exchange, defi, wrapped-tokens, fan...
#  max_supply                                                         None
#  circulating_supply                                        242880.531551
#  total_supply                                              242880.531551
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             15
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 55902.168222801454, 'volume_...
#  dtype: object,
#  id                                                                 4687
#  name                                                        Binance USD
#  symbol                                                             BUSD
#  slug                                                        binance-usd
#  num_market_pairs                                                   1576
#  date_added                                     2019-09-20T00:00:00.000Z
#  tags                  [stablecoin, asset-backed-stablecoin, binance-...
#  max_supply                                                         None
#  circulating_supply                                       13087809174.25
#  total_supply                                             13087809174.25
#  platform              {'id': 1839, 'name': 'Binance Chain (BEP2)', '...
#  cmc_rank                                                             16
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 1.0010412686904593, 'volume_...
#  dtype: object,
#  id                                                                 3635
#  name                                                    Crypto.com Coin
#  symbol                                                              CRO
#  slug                                                    crypto-com-coin
#  num_market_pairs                                                    113
#  date_added                                     2018-12-14T00:00:00.000Z
#  tags                  [medium-of-exchange, cosmos-ecosystem, central...
#  max_supply                                                  30263013692
#  circulating_supply                                          25263013692
#  total_supply                                                30263013692
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             17
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 0.5024076219213037, 'volume_...
#  dtype: object,
#  id                                                                 7083
#  name                                                            Uniswap
#  symbol                                                              UNI
#  slug                                                            uniswap
#  num_market_pairs                                                    284
#  date_added                                     2020-09-17T00:00:00.000Z
#  tags                  [decentralized-exchange, defi, dao, yield-farm...
#  max_supply                                                   1000000000
#  circulating_supply                                     627823666.772673
#  total_supply                                                 1000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             18
#  last_updated                                   2021-11-18T22:49:11.000Z
#  quote                 {'USD': {'price': 20.054490667698126, 'volume_...
#  dtype: object,
#  id                                                                 1975
#  name                                                          Chainlink
#  symbol                                                             LINK
#  slug                                                          chainlink
#  num_market_pairs                                                    476
#  date_added                                     2017-09-20T00:00:00.000Z
#  tags                  [platform, defi, oracles, smart-contracts, sub...
#  max_supply                                                   1000000000
#  circulating_supply                                     465509553.917464
#  total_supply                                                 1000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             19
#  last_updated                                   2021-11-18T22:49:10.000Z
#  quote                 {'USD': {'price': 26.401898160119085, 'volume_...
#  dtype: object,
#  id                                                                 4030
#  name                                                           Algorand
#  symbol                                                             ALGO
#  slug                                                           algorand
#  num_market_pairs                                                    157
#  date_added                                     2019-06-20T00:00:00.000Z
#  tags                  [pos, platform, research, smart-contracts, arr...
#  max_supply                                                  10000000000
#  circulating_supply                                    6252500865.738343
#  total_supply                                          6710847416.243278
#  platform                                                           None
#  cmc_rank                                                             20
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 1.8323543025189026, 'volume_...
#  dtype: object,
#  id                                                                 1831
#  name                                                       Bitcoin Cash
#  symbol                                                              BCH
#  slug                                                       bitcoin-cash
#  num_market_pairs                                                    523
#  date_added                                     2017-07-23T00:00:00.000Z
#  tags                  [mineable, pow, sha-256, marketplace, medium-o...
#  max_supply                                                     21000000
#  circulating_supply                                          18904143.75
#  total_supply                                                18904143.75
#  platform                                                           None
#  cmc_rank                                                             21
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 553.3253019953149, 'volume_2...
#  dtype: object,
#  id                                                                 3890
#  name                                                            Polygon
#  symbol                                                            MATIC
#  slug                                                            polygon
#  num_market_pairs                                                    255
#  date_added                                     2019-04-28T00:00:00.000Z
#  tags                  [platform, enterprise-solutions, state-channel...
#  max_supply                                                  10000000000
#  circulating_supply                                        6942890165.27
#  total_supply                                                10000000000
#  platform                                                           None
#  cmc_rank                                                             22
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 1.4895270459724235, 'volume_...
#  dtype: object,
#  id                                                                 3077
#  name                                                            VeChain
#  symbol                                                              VET
#  slug                                                            vechain
#  num_market_pairs                                                    150
#  date_added                                     2017-08-22T00:00:00.000Z
#  tags                  [logistics, data-provenance, iot, smart-contra...
#  max_supply                                                  86712634466
#  circulating_supply                                          64315576989
#  total_supply                                                86712634466
#  platform                                                           None
#  cmc_rank                                                             23
#  last_updated                                   2021-11-18T22:50:02.000Z
#  quote                 {'USD': {'price': 0.12888751924761194, 'volume...
#  dtype: object,
#  id                                                                  512
#  name                                                            Stellar
#  symbol                                                              XLM
#  slug                                                            stellar
#  num_market_pairs                                                    325
#  date_added                                     2014-08-05T00:00:00.000Z
#  tags                  [medium-of-exchange, enterprise-solutions, dec...
#  max_supply                                                  50001806812
#  circulating_supply                                   24276097691.580791
#  total_supply                                         50001802585.975151
#  platform                                                           None
#  cmc_rank                                                             24
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 0.3256369414165048, 'volume_...
#  dtype: object,
#  id                                                                 6783
#  name                                                      Axie Infinity
#  symbol                                                              AXS
#  slug                                                      axie-infinity
#  num_market_pairs                                                    138
#  date_added                                     2020-08-31T00:00:00.000Z
#  tags                  [collectibles-nfts, gaming, binance-launchpad,...
#  max_supply                                                    270000000
#  circulating_supply                                             60907500
#  total_supply                                                  270000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             25
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 123.88118024478057, 'volume_...
#  dtype: object,
#  id                                                                 8916
#  name                                                  Internet Computer
#  symbol                                                              ICP
#  slug                                                  internet-computer
#  num_market_pairs                                                     82
#  date_added                                     2021-03-23T00:00:00.000Z
#  tags                  [platform, distributed-computing, polychain-ca...
#  max_supply                                                         None
#  circulating_supply                                         182306035.45
#  total_supply                                           474774584.194905
#  platform                                                           None
#  cmc_rank                                                             26
#  last_updated                                   2021-11-18T22:50:09.000Z
#  quote                 {'USD': {'price': 39.749528308493055, 'volume_...
#  dtype: object,
#  id                                                                 1958
#  name                                                               TRON
#  symbol                                                              TRX
#  slug                                                               tron
#  num_market_pairs                                                    487
#  date_added                                     2017-09-13T00:00:00.000Z
#  tags                  [media, payments, tron-ecosystem, binance-smar...
#  max_supply                                                         None
#  circulating_supply                                   71659657369.490005
#  total_supply                                        100850743811.662003
#  platform                                                           None
#  cmc_rank                                                             27
#  last_updated                                   2021-11-18T22:49:10.000Z
#  quote                 {'USD': {'price': 0.10039920817345016, 'volume...
#  dtype: object,
#  id                                                                 4195
#  name                                                          FTX Token
#  symbol                                                              FTT
#  slug                                                          ftx-token
#  num_market_pairs                                                     89
#  date_added                                     2019-07-31T00:00:00.000Z
#  tags                  [marketplace, centralized-exchange, derivative...
#  max_supply                                                    352170015
#  circulating_supply                                     139739224.618744
#  total_supply                                           335608560.685971
#  platform              {'id': 1839, 'name': 'Binance Chain (BEP2)', '...
#  cmc_rank                                                             28
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 50.41919926644659, 'volume_2...
#  dtype: object,
#  id                                                                 1966
#  name                                                       Decentraland
#  symbol                                                             MANA
#  slug                                                       decentraland
#  num_market_pairs                                                    187
#  date_added                                     2017-09-17T00:00:00.000Z
#  tags                  [platform, collectibles-nfts, gaming, payments...
#  max_supply                                                         None
#  circulating_supply                                    1816915691.495089
#  total_supply                                          2193995927.320146
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             29
#  last_updated                                   2021-11-18T22:49:10.000Z
#  quote                 {'USD': {'price': 3.8113445241551926, 'volume_...
#  dtype: object,
#  id                                                                 7129
#  name                                                           TerraUSD
#  symbol                                                              UST
#  slug                                                           terrausd
#  num_market_pairs                                                    108
#  date_added                                     2020-09-21T00:00:00.000Z
#  tags                  [stablecoin, binance-smart-chain, terra-ecosys...
#  max_supply                                                         None
#  circulating_supply                                    6522133776.328217
#  total_supply                                          6522133776.328217
#  platform                                                           None
#  cmc_rank                                                             30
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 1.0007600783748367, 'volume_...
#  dtype: object,
#  id                                                                 4943
#  name                                                                Dai
#  symbol                                                              DAI
#  slug                                               multi-collateral-dai
#  num_market_pairs                                                    429
#  date_added                                     2019-11-22T00:00:00.000Z
#  tags                  [defi, stablecoin, ethereum-ecosystem, binance...
#  max_supply                                                         None
#  circulating_supply                                    6474951713.635377
#  total_supply                                          6474952202.474523
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             31
#  last_updated                                   2021-11-18T22:49:10.000Z
#  quote                 {'USD': {'price': 0.9972986983086395, 'volume_...
#  dtype: object,
#  id                                                                 2280
#  name                                                           Filecoin
#  symbol                                                              FIL
#  slug                                                           filecoin
#  num_market_pairs                                                    154
#  date_added                                     2017-12-13T00:00:00.000Z
#  tags                  [mineable, distributed-computing, filesharing,...
#  max_supply                                                         None
#  circulating_supply                                            123491939
#  total_supply                                                  123491939
#  platform                                                           None
#  cmc_rank                                                             32
#  last_updated                                   2021-11-18T22:50:04.000Z
#  quote                 {'USD': {'price': 51.935109490632186, 'volume_...
#  dtype: object,
#  id                                                                 1321
#  name                                                   Ethereum Classic
#  symbol                                                              ETC
#  slug                                                   ethereum-classic
#  num_market_pairs                                                    257
#  date_added                                     2016-07-24T00:00:00.000Z
#  tags                  [mineable, pow, ethash, platform, smart-contra...
#  max_supply                                                    210700000
#  circulating_supply                                      131076372.19529
#  total_supply                                                  210700000
#  platform                                                           None
#  cmc_rank                                                             33
#  last_updated                                   2021-11-18T22:50:05.000Z
#  quote                 {'USD': {'price': 48.306831153851654, 'volume_...
#  dtype: object,
#  id                                                                 6892
#  name                                                             Elrond
#  symbol                                                             EGLD
#  slug                                                        elrond-egld
#  num_market_pairs                                                     58
#  date_added                                     2020-09-04T00:00:00.000Z
#  tags                  [binance-smart-chain, binance-launchpad, binan...
#  max_supply                                                     31415926
#  circulating_supply                                      19754907.345307
#  total_supply                                                   22748693
#  platform                                                           None
#  cmc_rank                                                             34
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 305.9669717670095, 'volume_2...
#  dtype: object,
#  id                                                                 4023
#  name                                                       Bitcoin BEP2
#  symbol                                                             BTCB
#  slug                                                       bitcoin-bep2
#  num_market_pairs                                                     61
#  date_added                                     2019-06-18T00:00:00.000Z
#  tags                               [binance-chain, binance-smart-chain]
#  max_supply                                                         None
#  circulating_supply                                        105114.333125
#  total_supply                                                     112501
#  platform              {'id': 1839, 'name': 'Binance Chain (BEP2)', '...
#  cmc_rank                                                             35
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 57284.54033280582, 'volume_2...
#  dtype: object,
#  id                                                                 2416
#  name                                                              THETA
#  symbol                                                            THETA
#  slug                                                              theta
#  num_market_pairs                                                     82
#  date_added                                     2018-01-17T00:00:00.000Z
#  tags                  [media, collectibles-nfts, content-creation, v...
#  max_supply                                                   1000000000
#  circulating_supply                                           1000000000
#  total_supply                                                 1000000000
#  platform                                                           None
#  cmc_rank                                                             36
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 5.967636307163195, 'volume_2...
#  dtype: object,
#  id                                                                 3794
#  name                                                             Cosmos
#  symbol                                                             ATOM
#  slug                                                             cosmos
#  num_market_pairs                                                    187
#  date_added                                     2019-03-14T00:00:00.000Z
#  tags                  [platform, cosmos-ecosystem, content-creation,...
#  max_supply                                                         None
#  circulating_supply                                     224782079.124972
#  total_supply                                           282566682.124972
#  platform                                                           None
#  cmc_rank                                                             37
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 26.411503487348973, 'volume_...
#  dtype: object,
#  id                                                                 4642
#  name                                                             Hedera
#  symbol                                                             HBAR
#  slug                                                             hedera
#  num_market_pairs                                                     70
#  date_added                                     2019-09-17T00:00:00.000Z
#  tags                  [dag, marketplace, enterprise-solutions, payme...
#  max_supply                                                  50000000000
#  circulating_supply                                    15018941582.14876
#  total_supply                                                50000000000
#  platform                                                           None
#  cmc_rank                                                             38
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 0.36099850640990416, 'volume...
#  dtype: object,
#  id                                                                 6535
#  name                                                      NEAR Protocol
#  symbol                                                             NEAR
#  slug                                                      near-protocol
#  num_market_pairs                                                     71
#  date_added                                     2020-08-11T00:00:00.000Z
#  tags                  [platform, staking, binance-smart-chain, coinb...
#  max_supply                                                   1000000000
#  circulating_supply                                            548382034
#  total_supply                                                 1000000000
#  platform                                                           None
#  cmc_rank                                                             39
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 8.759080123436455, 'volume_2...
#  dtype: object,
#  id                                                                 3513
#  name                                                             Fantom
#  symbol                                                              FTM
#  slug                                                             fantom
#  num_market_pairs                                                    121
#  date_added                                     2018-10-29T00:00:00.000Z
#  tags                  [platform, enterprise-solutions, defi, researc...
#  max_supply                                                   3175000000
#  circulating_supply                                           2545006273
#  total_supply                                                 2545006273
#  platform                                                           None
#  cmc_rank                                                             40
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 1.8275279926090737, 'volume_...
#  dtype: object,
#  id                                                                 2011
#  name                                                              Tezos
#  symbol                                                              XTZ
#  slug                                                              tezos
#  num_market_pairs                                                    174
#  date_added                                     2017-10-06T00:00:00.000Z
#  tags                  [pos, platform, enterprise-solutions, collecti...
#  max_supply                                                         None
#  circulating_supply                                     867424482.728573
#  total_supply                                           896249752.826749
#  platform                                                           None
#  cmc_rank                                                             41
#  last_updated                                   2021-11-18T22:49:11.000Z
#  quote                 {'USD': {'price': 4.7963955171792145, 'volume_...
#  dtype: object,
#  id                                                                 6719
#  name                                                          The Graph
#  symbol                                                              GRT
#  slug                                                          the-graph
#  num_market_pairs                                                    137
#  date_added                                     2020-12-17T00:00:00.000Z
#  tags                  [ai-big-data, enterprise-solutions, defi, bina...
#  max_supply                                                  10057044431
#  circulating_supply                                           4715735200
#  total_supply                                                10000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             42
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 0.8715119890702874, 'volume_...
#  dtype: object,
#  id                                                                 5665
#  name                                                             Helium
#  symbol                                                              HNT
#  slug                                                             helium
#  num_market_pairs                                                     32
#  date_added                                     2020-06-05T00:00:00.000Z
#  tags                  [mineable, enterprise-solutions, distributed-c...
#  max_supply                                                    223000000
#  circulating_supply                                     102232714.957302
#  total_supply                                                  223000000
#  platform                                                           None
#  cmc_rank                                                             43
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 39.90426387117144, 'volume_2...
#  dtype: object,
#  id                                                                  328
#  name                                                             Monero
#  symbol                                                              XMR
#  slug                                                             monero
#  num_market_pairs                                                    149
#  date_added                                     2014-05-21T00:00:00.000Z
#  tags                  [mineable, pow, medium-of-exchange, privacy, r...
#  max_supply                                                         None
#  circulating_supply                                      18014103.584424
#  total_supply                                            18014103.584424
#  platform                                                           None
#  cmc_rank                                                             44
#  last_updated                                   2021-11-18T22:50:05.000Z
#  quote                 {'USD': {'price': 225.4316536373739, 'volume_2...
#  dtype: object,
#  id                                                                 6210
#  name                                                        The Sandbox
#  symbol                                                             SAND
#  slug                                                        the-sandbox
#  num_market_pairs                                                    128
#  date_added                                     2020-08-05T00:00:00.000Z
#  tags                  [collectibles-nfts, content-creation, gaming, ...
#  max_supply                                                   3000000000
#  circulating_supply                                     892246119.223323
#  total_supply                                                 3000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                             45
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 4.505164776953496, 'volume_2...
#  dtype: object,
#  id                                                                 1765
#  name                                                                EOS
#  symbol                                                              EOS
#  slug                                                                eos
#  num_market_pairs                                                    384
#  date_added                                     2017-07-01T00:00:00.000Z
#  tags                  [medium-of-exchange, enterprise-solutions, sma...
#  max_supply                                                         None
#  circulating_supply                                        971638951.484
#  total_supply                                            1039639363.3691
#  platform                                                           None
#  cmc_rank                                                             46
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 4.082829783546033, 'volume_2...
#  dtype: object,
#  id                                                                 4256
#  name                                                             Klaytn
#  symbol                                                             KLAY
# ...
#  total_supply                                                 3000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            985
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 0.03452330227867354, 'volume...
#  dtype: object,
#  id                                                                 1681
#  name                                                              PRIZM
#  symbol                                                              PZM
#  slug                                                              prizm
#  num_market_pairs                                                     11
#  date_added                                     2017-05-19T00:00:00.000Z
#  tags                                                 [marketplace, iot]
#  max_supply                                                   6000000000
#  circulating_supply                                        2898546765.49
#  total_supply                                                 6000000000
#  platform                                                           None
#  cmc_rank                                                            986
#  last_updated                                   2021-11-18T22:50:08.000Z
#  quote                 {'USD': {'price': 0.0053343163588407405, 'volu...
#  dtype: object,
#  id                                                                 8006
#  name                                                   Mirrored Alibaba
#  symbol                                                            mBABA
#  slug                                                   mirrored-alibaba
#  num_market_pairs                                                      1
#  date_added                                     2020-12-15T00:00:00.000Z
#  tags                                                  [tokenized-stock]
#  max_supply                                                         None
#  circulating_supply                                         98924.466534
#  total_supply                                               98924.466534
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            987
#  last_updated                                   2021-11-18T22:49:09.000Z
#  quote                 {'USD': {'price': 155.8164027454426, 'volume_2...
#  dtype: object,
#  id                                                                 3831
#  name                                                         Safe Haven
#  symbol                                                              SHA
#  slug                                                         safe-haven
#  num_market_pairs                                                      7
#  date_added                                     2019-04-02T00:00:00.000Z
#  tags                                                [polygon-ecosystem]
#  max_supply                                                         None
#  circulating_supply                                           3005855396
#  total_supply                                                 8500000000
#  platform                                                           None
#  cmc_rank                                                            988
#  last_updated                                   2021-11-18T22:50:09.000Z
#  quote                 {'USD': {'price': 0.005112105456332333, 'volum...
#  dtype: object,
#  id                                                                 4277
#  name                                                             DECOIN
#  symbol                                                             DTEP
#  slug                                                             decoin
#  num_market_pairs                                                      4
#  date_added                                     2019-08-22T00:00:00.000Z
#  tags                  [mineable, decentralized-exchange, algorand-ec...
#  max_supply                                                    140000000
#  circulating_supply                                      55864121.050017
#  total_supply                                            78427591.562045
#  platform                                                           None
#  cmc_rank                                                            989
#  last_updated                                   2021-11-18T22:50:04.000Z
#  quote                 {'USD': {'price': 0.272557678362112, 'volume_2...
#  dtype: object,
#  id                                                                 8620
#  name                                                              TOWER
#  symbol                                                            TOWER
#  slug                                                        tower-token
#  num_market_pairs                                                     24
#  date_added                                     2021-03-01T00:00:00.000Z
#  tags                  [collectibles-nfts, gaming, entertainment, gov...
#  max_supply                                                  10000000000
#  circulating_supply                                     237619986.660692
#  total_supply                                                10000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            990
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 0.06361814439778686, 'volume...
#  dtype: object,
#  id                                                                 3609
#  name                                                          CWV Chain
#  symbol                                                              CWV
#  slug                                                          cwv-chain
#  num_market_pairs                                                      2
#  date_added                                     2018-11-16T00:00:00.000Z
#  tags                              [platform, payments, smart-contracts]
#  max_supply                                                         None
#  circulating_supply                                      3540912310.9992
#  total_supply                                                10000000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            991
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 0.00426490132557586, 'volume...
#  dtype: object,
#  id                                                                 8416
#  name                                                            Finxflo
#  symbol                                                              FXF
#  slug                                                            finxflo
#  num_market_pairs                                                      5
#  date_added                                     2021-02-09T00:00:00.000Z
#  tags                  [binance-smart-chain, polkastarter, exnetwork-...
#  max_supply                                                    150000000
#  circulating_supply                                      71808092.866737
#  total_supply                                                  150000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            992
#  last_updated                                   2021-11-18T22:50:04.000Z
#  quote                 {'USD': {'price': 0.21030138752362398, 'volume...
#  dtype: object,
#  id                                                                 1087
#  name                                                             Factom
#  symbol                                                              FCT
#  slug                                                             factom
#  num_market_pairs                                                      3
#  date_added                                     2015-10-06T00:00:00.000Z
#  tags                  [services, enterprise-solutions, data-provenan...
#  max_supply                                                         None
#  circulating_supply                                      10123949.220447
#  total_supply                                            10123949.220447
#  platform                                                           None
#  cmc_rank                                                            993
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 1.4852170499333326, 'volume_...
#  dtype: object,
#  id                                                                 8494
#  name                                                             Modefi
#  symbol                                                              MOD
#  slug                                                             modefi
#  num_market_pairs                                                      7
#  date_added                                     2021-02-17T00:00:00.000Z
#  tags                  [oracles, binance-smart-chain, trustswap-launc...
#  max_supply                                                     22000000
#  circulating_supply                                      14037696.416667
#  total_supply                                                   22000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            994
#  last_updated                                   2021-11-18T22:50:05.000Z
#  quote                 {'USD': {'price': 1.0704625269293973, 'volume_...
#  dtype: object,
#  id                                                                 9828
#  name                                                             Nafter
#  symbol                                                             NAFT
#  slug                                                             nafter
#  num_market_pairs                                                      5
#  date_added                                     2021-05-15T00:00:00.000Z
#  tags                           [collectibles-nfts, binance-smart-chain]
#  max_supply                                                   1000000000
#  circulating_supply                                            500000000
#  total_supply                                                 1000000000
#  platform              {'id': 1839, 'name': 'Binance Smart Chain (BEP...
#  cmc_rank                                                            996
#  last_updated                                   2021-11-18T22:50:07.000Z
#  quote                 {'USD': {'price': 0.030052872977958025, 'volum...
#  dtype: object,
#  id                                                                11977
#  name                                                       Infinity PAD
#  symbol                                                             IPAD
#  slug                                                       infinity-pad
#  num_market_pairs                                                      3
#  date_added                                     2021-09-20T17:03:19.000Z
#  tags                                                                 []
#  max_supply                                                   1000000000
#  circulating_supply                                            540000000
#  total_supply                                                  200000000
#  platform              {'id': 1839, 'name': 'Binance Smart Chain (BEP...
#  cmc_rank                                                            995
#  last_updated                                   2021-11-18T22:50:09.000Z
#  quote                 {'USD': {'price': 0.02781297930734551, 'volume...
#  dtype: object,
#  id                                                                 8695
#  name                                                       Blank Wallet
#  symbol                                                            BLANK
#  slug                                                       blank-wallet
#  num_market_pairs                                                      5
#  date_added                                     2021-03-04T00:00:00.000Z
#  tags                                                     [polkastarter]
#  max_supply                                                    125000000
#  circulating_supply                                             19394814
#  total_supply                                           124999999.999984
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            997
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 0.7735448174257783, 'volume_...
#  dtype: object,
#  id                                                                 8168
#  name                                                        Bao Finance
#  symbol                                                              BAO
#  slug                                                        bao-finance
#  num_market_pairs                                                     14
#  date_added                                     2021-01-04T00:00:00.000Z
#  tags                        [yield-farming, alameda-research-portfolio]
#  max_supply                                                         None
#  circulating_supply                                          34066471176
#  total_supply                                               560270974250
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                           1002
#  last_updated                                   2021-11-18T22:49:11.000Z
#  quote                 {'USD': {'price': 0.0004355847988463899, 'volu...
#  dtype: object,
#  id                                                                 6638
#  name                                                           UniLayer
#  symbol                                                            LAYER
#  slug                                                           unilayer
#  num_market_pairs                                                     15
#  date_added                                     2020-08-19T00:00:00.000Z
#  tags                  [collectibles-nfts, decentralized-exchange, defi]
#  max_supply                                                     40000000
#  circulating_supply                                             25090721
#  total_supply                                                   40000000
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                            998
#  last_updated                                   2021-11-18T22:50:06.000Z
#  quote                 {'USD': {'price': 0.5933035647729421, 'volume_...
#  dtype: object,
#  id                                                                 7216
#  name                                                            LuaSwap
#  symbol                                                              LUA
#  slug                                                          lua-token
#  num_market_pairs                                                     12
#  date_added                                     2020-09-29T00:00:00.000Z
#  tags                  [decentralized-exchange, defi, yield-farming, ...
#  max_supply                                                    500000000
#  circulating_supply                                     125579949.348715
#  total_supply                                           221829982.318967
#  platform              {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#  cmc_rank                                                           1000
#  last_updated                                   2021-11-18T22:50:03.000Z
#  quote                 {'USD': {'price': 0.11834491553399225, 'volume...
#  dtype: object]

# %%
amount = 1
symbol = 'BTC'
convert_url = 'https://pro-api.coinmarketcap.com/v1/tools/price-conversion'

parameters = {
    'amount': amount,
    'symbol': symbol,
    'convert': 'USD'
}
response = session.get(convert_url, params=parameters)
data = json.loads(response.text)
quote = []
for row in data['data']:
    quote.append(row)
quote
# Out:
# ['status', 'data']

# %%
amount = 1
symbol = 'BTC'
convert_url = 'https://pro-api.coinmarketcap.com/v1/tools/price-conversion'

def get_crypto_prices():
    parameters = {
        'amount': amount,
        'symbol': cryptocurrency,
        'convert': 'USD'
    }
    response = session.get(convert_url, params=parameters)
    data = json.loads(response.text)
    quote = []
    for row in data['data']:
        quote.append(row)

    return quote
get_crypto_prices()
# Out:
# ['id', 'symbol', 'name', 'amount', 'last_updated', 'quote']

# %%
symbol_df = pd.DataFrame(crypto, columns=['symbol', 'id'])
symbol_df
# Out:
#     symbol     id
# 0      BTC      1
# 1      ETH   1027
# 2      BNB   1839
# 3     USDT    825
# 4      ADA   2010
# ..     ...    ...
# 995    MOD   8494
# 996   IPAD  11977
# 997    FCT   1087
# 998  LAYER   6638
# 999   SYLO   5662
#
# [1000 rows x 2 columns]

# %%
crypto_df = pd.DataFrame(
    crypto,
    columns=['symbol','quote']
)
crypto_df
# Out:
#     symbol                                              quote
# 0      BTC  {'USD': {'price': 57994.65587997932, 'volume_2...
# 1      ETH  {'USD': {'price': 4065.901284038366, 'volume_2...
# 2      BNB  {'USD': {'price': 537.7969496464726, 'volume_2...
# 3     USDT  {'USD': {'price': 1.0005964151121118, 'volume_...
# 4      SOL  {'USD': {'price': 199.45367203752403, 'volume_...
# ..     ...                                                ...
# 995  LAYER  {'USD': {'price': 0.6004861404332555, 'volume_...
# 996   IPAD  {'USD': {'price': 0.02786019061580374, 'volume...
# 997   NAFT  {'USD': {'price': 0.030055386574282784, 'volum...
# 998    BAO  {'USD': {'price': 0.00043789484751042147, 'vol...
# 999  TOWER  {'USD': {'price': 0.06301969510928497, 'volume...
#
# [1000 rows x 2 columns]

# %%
quote_df = crypto_df['quote']
quote_list = quote_df.tolist()
quote_list
# Out:
# [{'USD': {'price': 57994.65587997932,
#    'volume_24h': 41041991475.192604,
#    'volume_change_24h': 3.1449,
#    'percent_change_1h': -0.48351579,
#    'percent_change_24h': -4.1530963,
#    'percent_change_7d': -10.78297919,
#    'percent_change_30d': -9.80137643,
#    'percent_change_60d': 21.94115942,
#    'percent_change_90d': 19.01222242,
#    'market_cap': 1094765119046.3696,
#    'market_cap_dominance': 43.4748,
#    'fully_diluted_market_cap': 1217887773479.57,
#    'last_updated': '2021-11-18T20:39:02.000Z'}},
#  {'USD': {'price': 4065.901284038366,
#    'volume_24h': 20781249778.66806,
#    'volume_change_24h': -9.1313,
#    'percent_change_1h': -0.56657461,
#    'percent_change_24h': -4.55294253,
#    'percent_change_7d': -14.19322228,
#    'percent_change_30d': 6.47789831,
#    'percent_change_60d': 20.89006356,
#    'percent_change_90d': 24.51159462,
#    'market_cap': 481384235554.1666,
#    'market_cap_dominance': 19.1202,
#    'fully_diluted_market_cap': 481384235554.17,
#    'last_updated': '2021-11-18T20:39:02.000Z'}},
#  {'USD': {'price': 537.7969496464726,
#    'volume_24h': 2879984773.2224994,
#    'volume_change_24h': 1.6537,
#    'percent_change_1h': -0.92403056,
#    'percent_change_24h': -7.19276357,
#    'percent_change_7d': -14.29789072,
#    'percent_change_30d': 11.42173019,
#    'percent_change_60d': 29.71764444,
#    'percent_change_90d': 19.53670067,
#    'market_cap': 89705148591.92982,
#    'market_cap_dominance': 3.563,
#    'fully_diluted_market_cap': 89705148591.93,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 1.0005964151121118,
#    'volume_24h': 92971214481.91884,
#    'volume_change_24h': 8.3031,
#    'percent_change_1h': 0.03076144,
#    'percent_change_24h': 0.12670568,
#    'percent_change_7d': 0.02839915,
#    'percent_change_30d': 0.04850012,
#    'percent_change_60d': -0.00565749,
#    'percent_change_90d': 0.02897056,
#    'market_cap': 73805436169.75308,
#    'market_cap_dominance': 2.931,
#    'fully_diluted_market_cap': 76402592171.74,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 199.45367203752403,
#    'volume_24h': 3722591882.576299,
#    'volume_change_24h': 22.079,
#    'percent_change_1h': -0.99394558,
#    'percent_change_24h': -8.05141213,
#    'percent_change_7d': -15.37544022,
#    'percent_change_30d': 29.82279733,
#    'percent_change_60d': 27.77614846,
#    'percent_change_90d': 154.35987928,
#    'market_cap': 60535600884.944435,
#    'market_cap_dominance': 2.4039,
#    'fully_diluted_market_cap': 101560676536.37,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 1.8107947240291555,
#    'volume_24h': 2423492962.65623,
#    'volume_change_24h': -19.4348,
#    'percent_change_1h': -0.53216345,
#    'percent_change_24h': -3.3249737,
#    'percent_change_7d': -12.98203846,
#    'percent_change_30d': -13.82328688,
#    'percent_change_60d': -21.97943376,
#    'percent_change_90d': -27.70675269,
#    'market_cap': 60323451753.47182,
#    'market_cap_dominance': 2.3957,
#    'fully_diluted_market_cap': 81485762581.31,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 1.0534621904809587,
#    'volume_24h': 5307026444.79248,
#    'volume_change_24h': 38.7059,
#    'percent_change_1h': -0.58575721,
#    'percent_change_24h': -4.35460456,
#    'percent_change_7d': -13.02933814,
#    'percent_change_30d': -2.62187658,
#    'percent_change_60d': -1.96252028,
#    'percent_change_90d': -16.3136888,
#    'market_cap': 49680197020.05979,
#    'market_cap_dominance': 1.973,
#    'fully_diluted_market_cap': 105346219048.1,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 39.87766377910168,
#    'volume_24h': 2099346324.5509975,
#    'volume_change_24h': 5.7724,
#    'percent_change_1h': 0.17791291,
#    'percent_change_24h': -5.57260217,
#    'percent_change_7d': -17.41731685,
#    'percent_change_30d': -2.17946541,
#    'percent_change_60d': 15.99378883,
#    'percent_change_90d': 41.19319783,
#    'market_cap': 39382355877.0542,
#    'market_cap_dominance': 1.564,
#    'fully_diluted_market_cap': 43997164878.1,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 1.0001220135018243,
#    'volume_24h': 5854651517.800336,
#    'volume_change_24h': 9.8255,
#    'percent_change_1h': -0.01674445,
#    'percent_change_24h': 0.07243388,
#    'percent_change_7d': 0.02478331,
#    'percent_change_30d': 0.0199174,
#    'percent_change_60d': -0.04935693,
#    'percent_change_90d': 0.00646198,
#    'market_cap': 34428551819.52715,
#    'market_cap_dominance': 1.3672,
#    'fully_diluted_market_cap': 34428551819.53,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 0.2257147254315907,
#    'volume_24h': 1785803664.6276655,
#    'volume_change_24h': 11.9762,
#    'percent_change_1h': -0.84632628,
#    'percent_change_24h': -5.01477915,
#    'percent_change_7d': -13.53656617,
#    'percent_change_30d': -7.386243,
#    'percent_change_60d': -4.69901621,
#    'percent_change_90d': -30.65923141,
#    'market_cap': 29832272691.28906,
#    'market_cap_dominance': 1.1847,
#    'fully_diluted_market_cap': 29832272691.29,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 4.346261257842537e-05,
#    'volume_24h': 3289322115.162117,
#    'volume_change_24h': 31.3166,
#    'percent_change_1h': -2.83522677,
#    'percent_change_24h': -9.27747986,
#    'percent_change_7d': -20.68751502,
#    'percent_change_30d': 55.39630753,
#    'percent_change_60d': 424.41186981,
#    'percent_change_90d': 414.84405404,
#    'market_cap': 23863406157.35435,
#    'market_cap_dominance': 0.9477,
#    'fully_diluted_market_cap': 25631522541.34,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 101.05649329134002,
#    'volume_24h': 1854210100.4099371,
#    'volume_change_24h': -29.2862,
#    'percent_change_1h': 0.34937928,
#    'percent_change_24h': -6.21206079,
#    'percent_change_7d': 15.48443306,
#    'percent_change_30d': 80.46202185,
#    'percent_change_60d': 39.80251027,
#    'percent_change_90d': 172.66743598,
#    'market_cap': 22261389011.747147,
#    'market_cap_dominance': 0.8842,
#    'fully_diluted_market_cap': 72760675169.76,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 41.56295674903321,
#    'volume_24h': 1244889681.6975617,
#    'volume_change_24h': 10.7645,
#    'percent_change_1h': -0.56920938,
#    'percent_change_24h': -5.18335523,
#    'percent_change_7d': -17.51049048,
#    'percent_change_30d': 14.26352073,
#    'percent_change_60d': 19.32844165,
#    'percent_change_90d': 39.26487404,
#    'market_cap': 17288527905.25201,
#    'market_cap_dominance': 0.6865,
#    'fully_diluted_market_cap': 37112196068.23,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 208.09464818295905,
#    'volume_24h': 3025054581.403078,
#    'volume_change_24h': 2.1883,
#    'percent_change_1h': -1.06127775,
#    'percent_change_24h': -9.41255453,
#    'percent_change_7d': -20.78887322,
#    'percent_change_30d': 11.94047735,
#    'percent_change_60d': 17.52642846,
#    'percent_change_90d': 14.68083596,
#    'market_cap': 14359003091.012592,
#    'market_cap_dominance': 0.5702,
#    'fully_diluted_market_cap': 17479950447.37,
#    'last_updated': '2021-11-18T20:39:02.000Z'}},
#  {'USD': {'price': 56913.212943902574,
#    'volume_24h': 306600846.4633014,
#    'volume_change_24h': 1.4806,
#    'percent_change_1h': -0.38595126,
#    'percent_change_24h': -3.88593735,
#    'percent_change_7d': -11.92008533,
#    'percent_change_30d': -11.5544279,
#    'percent_change_60d': 19.69240914,
#    'percent_change_90d': 16.75863741,
#    'market_cap': 13823111412.073807,
#    'market_cap_dominance': 0.549,
#    'fully_diluted_market_cap': 13823111412.07,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.5215168203666865,
#    'volume_24h': 1462420396.3215847,
#    'volume_change_24h': -7.8833,
#    'percent_change_1h': -1.74862705,
#    'percent_change_24h': -2.33425385,
#    'percent_change_7d': 49.94027349,
#    'percent_change_30d': 178.67603317,
#    'percent_change_60d': 180.38459331,
#    'percent_change_90d': 239.90516109,
#    'market_cap': 13175086573.531904,
#    'market_cap_dominance': 0.5232,
#    'fully_diluted_market_cap': 15782670675.37,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 1.0006360634413196,
#    'volume_24h': 8426640059.364168,
#    'volume_change_24h': 16.5657,
#    'percent_change_1h': 0.04598547,
#    'percent_change_24h': 0.05636369,
#    'percent_change_7d': 0.08004191,
#    'percent_change_30d': 0.07278204,
#    'percent_change_60d': -0.01843134,
#    'percent_change_90d': 0.0620268,
#    'market_cap': 13096133851.192707,
#    'market_cap_dominance': 0.5202,
#    'fully_diluted_market_cap': 13096133851.19,
#    'last_updated': '2021-11-18T20:38:07.000Z'}},
#  {'USD': {'price': 20.42936087822949,
#    'volume_24h': 320520573.67920613,
#    'volume_change_24h': 10.4896,
#    'percent_change_1h': -0.26780686,
#    'percent_change_24h': -5.87483836,
#    'percent_change_7d': -20.19204912,
#    'percent_change_30d': -19.77165329,
#    'percent_change_60d': -14.9230551,
#    'percent_change_90d': -28.38128675,
#    'market_cap': 12826036256.39223,
#    'market_cap_dominance': 0.5094,
#    'fully_diluted_market_cap': 20429360878.23,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 26.976592415023337,
#    'volume_24h': 1128383191.8521502,
#    'volume_change_24h': -0.7703,
#    'percent_change_1h': -1.33654682,
#    'percent_change_24h': -7.68987006,
#    'percent_change_7d': -22.89465945,
#    'percent_change_30d': 5.71382679,
#    'percent_change_60d': -2.71624971,
#    'percent_change_90d': -5.69391926,
#    'market_cap': 12557861501.33075,
#    'market_cap_dominance': 0.4987,
#    'fully_diluted_market_cap': 26976592415.02,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 1.9554701519286721,
#    'volume_24h': 4259480525.426709,
#    'volume_change_24h': 615.0355,
#    'percent_change_1h': 2.31359258,
#    'percent_change_24h': 18.09922102,
#    'percent_change_7d': -1.25031957,
#    'percent_change_30d': 15.63568724,
#    'percent_change_60d': -1.79025509,
#    'percent_change_90d': 73.06921161,
#    'market_cap': 12226457221.452545,
#    'market_cap_dominance': 0.4855,
#    'fully_diluted_market_cap': 19554701519.29,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 562.4303922873487,
#    'volume_24h': 1267987373.8088841,
#    'volume_change_24h': -0.3231,
#    'percent_change_1h': -0.52907506,
#    'percent_change_24h': -4.86515546,
#    'percent_change_7d': -16.73948776,
#    'percent_change_30d': -8.16600653,
#    'percent_change_60d': -8.81239917,
#    'percent_change_90d': -16.94922153,
#    'market_cap': 10632194681.369896,
#    'market_cap_dominance': 0.4222,
#    'fully_diluted_market_cap': 11811038238.03,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 1.5125306067689739,
#    'volume_24h': 1026162130.031239,
#    'volume_change_24h': -8.6451,
#    'percent_change_1h': -0.65168029,
#    'percent_change_24h': -7.9237974,
#    'percent_change_7d': -13.55109902,
#    'percent_change_30d': 4.75388386,
#    'percent_change_60d': 13.54899356,
#    'percent_change_90d': -1.07763399,
#    'market_cap': 10501333874.406176,
#    'market_cap_dominance': 0.417,
#    'fully_diluted_market_cap': 15125306067.69,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.13106274554051456,
#    'volume_24h': 869883246.8009651,
#    'volume_change_24h': -4.3026,
#    'percent_change_1h': -1.08557608,
#    'percent_change_24h': -9.70367721,
#    'percent_change_7d': -20.05199654,
#    'percent_change_30d': 13.89966352,
#    'percent_change_60d': 18.64557025,
#    'percent_change_90d': -2.51140928,
#    'market_cap': 8429376101.200681,
#    'market_cap_dominance': 0.3348,
#    'fully_diluted_market_cap': 11364795946.17,
#    'last_updated': '2021-11-18T20:39:02.000Z'}},
#  {'USD': {'price': 0.32867937721586654,
#    'volume_24h': 843286932.4786819,
#    'volume_change_24h': 13.3273,
#    'percent_change_1h': -0.37821731,
#    'percent_change_24h': -5.73523962,
#    'percent_change_7d': -17.49107968,
#    'percent_change_30d': -11.45716304,
#    'percent_change_60d': 3.16084681,
#    'percent_change_90d': -13.85044136,
#    'market_cap': 7982339520.332628,
#    'market_cap_dominance': 0.317,
#    'fully_diluted_market_cap': 16434562722.64,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 126.66522613776257,
#    'volume_24h': 654863454.5535825,
#    'volume_change_24h': 8.5773,
#    'percent_change_1h': -1.38151058,
#    'percent_change_24h': -4.93341865,
#    'percent_change_7d': -13.83294985,
#    'percent_change_30d': 4.84423145,
#    'percent_change_60d': 96.63480755,
#    'percent_change_90d': 73.0064491,
#    'market_cap': 7714862260.985774,
#    'market_cap_dominance': 0.3064,
#    'fully_diluted_market_cap': 34199611057.2,
#    'last_updated': '2021-11-18T20:38:07.000Z'}},
#  {'USD': {'price': 40.21279500527792,
#    'volume_24h': 347521838.572134,
#    'volume_change_24h': 13.2644,
#    'percent_change_1h': -0.72134286,
#    'percent_change_24h': -5.54287577,
#    'percent_change_7d': -16.20135397,
#    'percent_change_30d': -7.22389992,
#    'percent_change_60d': -30.1657492,
#    'percent_change_90d': -40.07445174,
#    'market_cap': 7331035231.775779,
#    'market_cap_dominance': 0.2912,
#    'fully_diluted_market_cap': 19092012060,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.10183108736303188,
#    'volume_24h': 2287060281.9497275,
#    'volume_change_24h': -4.4784,
#    'percent_change_1h': -0.87728237,
#    'percent_change_24h': -8.85091616,
#    'percent_change_7d': -6.39803388,
#    'percent_change_30d': 2.08034548,
#    'percent_change_60d': -3.27520869,
#    'percent_change_90d': 13.62508979,
#    'market_cap': 7297180829.997468,
#    'market_cap_dominance': 0.2898,
#    'fully_diluted_market_cap': 10269740903.71,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 50.84925239027821,
#    'volume_24h': 221906469.83834586,
#    'volume_change_24h': -23.8882,
#    'percent_change_1h': 0.22975687,
#    'percent_change_24h': -1.15455119,
#    'percent_change_7d': -14.85712609,
#    'percent_change_30d': -10.42488473,
#    'percent_change_60d': -17.12005992,
#    'percent_change_90d': 5.35004327,
#    'market_cap': 7105635101.460279,
#    'market_cap_dominance': 0.2822,
#    'fully_diluted_market_cap': 17907581977.02,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 1.0019691514994227,
#    'volume_24h': 150929200.74504745,
#    'volume_change_24h': 28.1623,
#    'percent_change_1h': -0.02007712,
#    'percent_change_24h': -0.03487118,
#    'percent_change_7d': -0.14026814,
#    'percent_change_30d': 0.12291864,
#    'percent_change_60d': -0.32388404,
#    'percent_change_90d': -0.15582239,
#    'market_cap': 6490229705.861069,
#    'market_cap_dominance': 0.2577,
#    'fully_diluted_market_cap': 6490229705.86,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 3.5807269658743595,
#    'volume_24h': 5001293734.241204,
#    'volume_change_24h': 98.8779,
#    'percent_change_1h': -0.20511168,
#    'percent_change_24h': 11.81568615,
#    'percent_change_7d': 34.16005334,
#    'percent_change_30d': 381.70487926,
#    'percent_change_60d': 341.87911249,
#    'percent_change_90d': 330.42951386,
#    'market_cap': 6505879727.402116,
#    'market_cap_dominance': 0.2584,
#    'fully_diluted_market_cap': 7856101096.12,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 52.48244074488678,
#    'volume_24h': 1479598818.235994,
#    'volume_change_24h': 87.566,
#    'percent_change_1h': -0.04809579,
#    'percent_change_24h': -6.88412338,
#    'percent_change_7d': -16.45658777,
#    'percent_change_30d': -16.2915156,
#    'percent_change_60d': -37.68050516,
#    'percent_change_90d': -28.3028607,
#    'market_cap': 6481158371.038672,
#    'market_cap_dominance': 0.2574,
#    'fully_diluted_market_cap': 6481158371.04,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 1.0002666004061243,
#    'volume_24h': 839895918.9506377,
#    'volume_change_24h': -8.1113,
#    'percent_change_1h': -0.03711137,
#    'percent_change_24h': -0.20382248,
#    'percent_change_7d': -0.40739384,
#    'percent_change_30d': 0.08563851,
#    'percent_change_60d': -0.07030098,
#    'percent_change_90d': -0.06813612,
#    'market_cap': 6476677938.391867,
#    'market_cap_dominance': 0.2572,
#    'fully_diluted_market_cap': 6476678427.36,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 48.9976873430278,
#    'volume_24h': 838277592.8967738,
#    'volume_change_24h': -0.0424,
#    'percent_change_1h': -0.26212896,
#    'percent_change_24h': -4.3075454,
#    'percent_change_7d': -14.00861935,
#    'percent_change_30d': -6.36550504,
#    'percent_change_60d': -12.7469381,
#    'percent_change_90d': -28.96105531,
#    'market_cap': 6422352156.707731,
#    'market_cap_dominance': 0.2551,
#    'fully_diluted_market_cap': 10323812723.18,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 311.4688272138476,
#    'volume_24h': 231346246.4679588,
#    'volume_change_24h': 54.5008,
#    'percent_change_1h': -1.64045194,
#    'percent_change_24h': 2.00046349,
#    'percent_change_7d': -3.15958449,
#    'percent_change_30d': 37.4406958,
#    'percent_change_60d': 35.89763352,
#    'percent_change_90d': 98.52366221,
#    'market_cap': 6153037822.561001,
#    'market_cap_dominance': 0.2444,
#    'fully_diluted_market_cap': 9785081627.06,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 6.105275544541871,
#    'volume_24h': 299877020.3935195,
#    'volume_change_24h': 12.9528,
#    'percent_change_1h': -0.24003816,
#    'percent_change_24h': -6.74362043,
#    'percent_change_7d': -16.63070107,
#    'percent_change_30d': 3.90245144,
#    'percent_change_60d': -1.42298756,
#    'percent_change_90d': -15.58097048,
#    'market_cap': 6105275544.541871,
#    'market_cap_dominance': 0.2425,
#    'fully_diluted_market_cap': 6105275544.54,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 57853.68055595782,
#    'volume_24h': 81770086.22772855,
#    'volume_change_24h': -18.9451,
#    'percent_change_1h': -0.22773106,
#    'percent_change_24h': -4.18459934,
#    'percent_change_7d': -11.16632403,
#    'percent_change_30d': -9.90928325,
#    'percent_change_60d': 21.76182646,
#    'percent_change_90d': 18.87403843,
#    'market_cap': 6081251124.176503,
#    'market_cap_dominance': 0.2415,
#    'fully_diluted_market_cap': 6508596916.23,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 26.72428389003785,
#    'volume_24h': 532313590.9849652,
#    'volume_change_24h': -8.9761,
#    'percent_change_1h': -0.25353504,
#    'percent_change_24h': -9.68514998,
#    'percent_change_7d': -19.1759171,
#    'percent_change_30d': -21.45296582,
#    'percent_change_60d': -37.23351859,
#    'percent_change_90d': 40.73874135,
#    'market_cap': 6007016733.880703,
#    'market_cap_dominance': 0.2386,
#    'fully_diluted_market_cap': 7551268868.93,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.3665364553882807,
#    'volume_24h': 190671808.27959648,
#    'volume_change_24h': 22.3942,
#    'percent_change_1h': -0.69853833,
#    'percent_change_24h': -10.49968688,
#    'percent_change_7d': -15.54080512,
#    'percent_change_30d': -0.81408094,
#    'percent_change_60d': -10.1201472,
#    'percent_change_90d': 49.31920427,
#    'market_cap': 5504989611.204463,
#    'market_cap_dominance': 0.2186,
#    'fully_diluted_market_cap': 18326822769.41,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 8.900244490313524,
#    'volume_24h': 298258255.3446951,
#    'volume_change_24h': 10.8028,
#    'percent_change_1h': -0.59149222,
#    'percent_change_24h': -7.19800215,
#    'percent_change_7d': -26.45431194,
#    'percent_change_30d': 11.15599212,
#    'percent_change_60d': -8.90611109,
#    'percent_change_90d': 104.46633232,
#    'market_cap': 4880734176.695423,
#    'market_cap_dominance': 0.1938,
#    'fully_diluted_market_cap': 8900244490.31,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 1.892527156115478,
#    'volume_24h': 912292480.6181026,
#    'volume_change_24h': 56.3962,
#    'percent_change_1h': -1.8626924,
#    'percent_change_24h': -13.79252503,
#    'percent_change_7d': -27.21256019,
#    'percent_change_30d': -19.70640127,
#    'percent_change_60d': 30.09529102,
#    'percent_change_90d': 280.97427408,
#    'market_cap': 4816493484.136742,
#    'market_cap_dominance': 0.1913,
#    'fully_diluted_market_cap': 6008773720.67,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 4.920596826043332,
#    'volume_24h': 214526392.22556752,
#    'volume_change_24h': 1.5025,
#    'percent_change_1h': -0.80195635,
#    'percent_change_24h': -5.98509109,
#    'percent_change_7d': -16.21938914,
#    'percent_change_30d': -26.22405531,
#    'percent_change_60d': -26.32694903,
#    'percent_change_90d': 33.53120577,
#    'market_cap': 4268246156.5464954,
#    'market_cap_dominance': 0.1695,
#    'fully_diluted_market_cap': 4410083689.1,
#    'last_updated': '2021-11-18T20:38:11.000Z'}},
#  {'USD': {'price': 0.8931977930362316,
#    'volume_24h': 291733380.2527901,
#    'volume_change_24h': 40.7154,
#    'percent_change_1h': -0.10558158,
#    'percent_change_24h': -4.31885803,
#    'percent_change_7d': -20.96284239,
#    'percent_change_30d': 17.17424405,
#    'percent_change_60d': 8.51944365,
#    'percent_change_90d': -14.06558369,
#    'market_cap': 4212084273.1832724,
#    'market_cap_dominance': 0.1673,
#    'fully_diluted_market_cap': 8982929890.24,
#    'last_updated': '2021-11-18T20:39:08.000Z'}},
#  {'USD': {'price': 40.8482376220741,
#    'volume_24h': 51914750.62898876,
#    'volume_change_24h': -21.4342,
#    'percent_change_1h': -0.43073614,
#    'percent_change_24h': -9.88595156,
#    'percent_change_7d': -15.20119676,
#    'percent_change_30d': 88.57445168,
#    'percent_change_60d': 104.79082773,
#    'percent_change_90d': 66.07984949,
#    'market_cap': 4176026233.325633,
#    'market_cap_dominance': 0.1658,
#    'fully_diluted_market_cap': 9109156989.72,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 229.26273922001738,
#    'volume_24h': 233846837.30690125,
#    'volume_change_24h': 0.3501,
#    'percent_change_1h': -0.73396412,
#    'percent_change_24h': -5.28405801,
#    'percent_change_7d': -14.67594718,
#    'percent_change_30d': -9.16932336,
#    'percent_change_60d': -13.84173147,
#    'percent_change_90d': -18.68235788,
#    'market_cap': 4129962732.3581476,
#    'market_cap_dominance': 0.164,
#    'fully_diluted_market_cap': 4129962732.36,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 4.131915446862614,
#    'volume_24h': 1168706996.3013256,
#    'volume_change_24h': 13.5661,
#    'percent_change_1h': -0.44042148,
#    'percent_change_24h': -4.90625787,
#    'percent_change_7d': -16.20696365,
#    'percent_change_30d': -6.15082366,
#    'percent_change_60d': -18.54041365,
#    'percent_change_90d': -22.9133308,
#    'market_cap': 4014695924.6833963,
#    'market_cap_dominance': 0.1594,
#    'fully_diluted_market_cap': 4295667876.94,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 4.478344054315341,
#    'volume_24h': 5578406493.660911,
#    'volume_change_24h': 51.3218,
#    'percent_change_1h': 2.77549491,
#    'percent_change_24h': 26.05117802,
#    'percent_change_7d': 82.16487885,
#    'percent_change_30d': 517.85220632,
#    'percent_change_60d': 495.16722639,
#    'percent_change_90d': 636.17468073,
#    'market_cap': 3995785103.0097036,
#    'market_cap_dominance': 0.1587,
#    'fully_diluted_market_cap': 13435032162.95,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 1.5093017194605023,
#    'volume_24h': 180927439.1246286,
#    'volume_change_24h': 4.4663,
#    'percent_change_1h': -0.6312199,
#    'percent_change_24h': -1.15438102,
#    'percent_change_7d': -3.11421817,
#    'percent_change_30d': -5.58349641,
#    'percent_change_60d': 21.4903937,
#    'percent_change_90d': -21.68567875,
#    'market_cap': 3808973493.5160766,
#    'market_cap_dominance': 0.1513,
#    'fully_diluted_market_cap': 16186607787.88,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 12.067893409740408,
#    'volume_24h': 236452526.61954138,
#    'volume_change_24h': 14.6044,
#    'percent_change_1h': 1.24192319,
#    'percent_change_24h': -5.64136521,
#    'percent_change_7d': -8.3089201,
#    'percent_change_30d': -9.11973145,
#    'percent_change_60d': -41.76378793,
#    'percent_change_90d': -48.0181151,
#    'market_cap': 3763437159.2609687,
#    'market_cap_dominance': 0.1495,
#    'fully_diluted_market_cap': 16632112362.3,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 15.167174599296278,
#    'volume_24h': 414214817.79614145,
#    'volume_change_24h': 6.7541,
#    'percent_change_1h': -0.20969773,
#    'percent_change_24h': -7.15480014,
#    'percent_change_7d': -19.52468969,
#    'percent_change_30d': -23.46166963,
#    'percent_change_60d': -35.0031037,
#    'percent_change_90d': -36.24595367,
#    'market_cap': 3675634482.3853827,
#    'market_cap_dominance': 0.146,
#    'fully_diluted_market_cap': 3675634482.39,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 1.2841802929566564,
#    'volume_24h': 173068676.0766311,
#    'volume_change_24h': -58.218,
#    'percent_change_1h': -1.20897351,
#    'percent_change_24h': -7.92422812,
#    'percent_change_7d': -3.0288107,
#    'percent_change_30d': 4.40586394,
#    'percent_change_60d': -17.47105676,
#    'percent_change_90d': 16.7449821,
#    'market_cap': 3569418013.104838,
#    'market_cap_dominance': 0.1418,
#    'fully_diluted_market_cap': 3569418013.1,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 263.72569969819483,
#    'volume_24h': 354519348.7631019,
#    'volume_change_24h': -3.0523,
#    'percent_change_1h': -0.65448214,
#    'percent_change_24h': -6.70642231,
#    'percent_change_7d': -15.51374832,
#    'percent_change_30d': -11.84486519,
#    'percent_change_60d': -23.89466834,
#    'percent_change_90d': -36.15633568,
#    'market_cap': 3494669992.738861,
#    'market_cap_dominance': 0.1388,
#    'fully_diluted_market_cap': 4219611195.17,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 20.286880371944868,
#    'volume_24h': 111822903.4095147,
#    'volume_change_24h': -17.9758,
#    'percent_change_1h': 0.01451529,
#    'percent_change_24h': -9.58390674,
#    'percent_change_7d': -18.62062119,
#    'percent_change_30d': 621.99590481,
#    'percent_change_60d': 773.91608768,
#    'percent_change_90d': 2422.03471274,
#    'market_cap': 3198164509.7095885,
#    'market_cap_dominance': 0.127,
#    'fully_diluted_market_cap': 20286880371.94,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.00016620463862210353,
#    'volume_24h': 142342235.6491891,
#    'volume_change_24h': -2.7532,
#    'percent_change_1h': -0.3841174,
#    'percent_change_24h': -7.0207645,
#    'percent_change_7d': -13.18122551,
#    'percent_change_30d': -10.62338949,
#    'percent_change_60d': -28.27652462,
#    'percent_change_90d': 162.25383635,
#    'market_cap': 3141344277.5504265,
#    'market_cap_dominance': 0.1248,
#    'fully_diluted_market_cap': 3490297411.06,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 2.302306401969343,
#    'volume_24h': 821841253.5076265,
#    'volume_change_24h': -12.5294,
#    'percent_change_1h': -1.85537628,
#    'percent_change_24h': -9.33150412,
#    'percent_change_7d': -29.53454781,
#    'percent_change_30d': 447.20777345,
#    'percent_change_60d': 399.09371271,
#    'percent_change_90d': 551.30007569,
#    'market_cap': 3058047203.103145,
#    'market_cap_dominance': 0.1214,
#    'fully_diluted_market_cap': 3164552142.36,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 3.121174092356021,
#    'volume_24h': 2752013.90868964,
#    'volume_change_24h': -0.9137,
#    'percent_change_1h': 0.55611041,
#    'percent_change_24h': -0.85788514,
#    'percent_change_7d': -3.39905709,
#    'percent_change_30d': 4.72113189,
#    'percent_change_60d': 2.84037079,
#    'percent_change_90d': 5.46991767,
#    'market_cap': 2977456915.8520274,
#    'market_cap_dominance': 0.1183,
#    'fully_diluted_market_cap': 3075104014.65,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 343.4753402399985,
#    'volume_24h': 124582297.21803765,
#    'volume_change_24h': -3.4563,
#    'percent_change_1h': -0.96540246,
#    'percent_change_24h': -6.61752451,
#    'percent_change_7d': -23.09142057,
#    'percent_change_30d': -7.75153909,
#    'percent_change_60d': -15.3918212,
#    'percent_change_90d': -1.47223145,
#    'market_cap': 2909269812.084236,
#    'market_cap_dominance': 0.1155,
#    'fully_diluted_market_cap': 3314955197.8,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 151.35764303040506,
#    'volume_24h': 252464660.0012712,
#    'volume_change_24h': 4.815,
#    'percent_change_1h': -0.73150378,
#    'percent_change_24h': -7.0361121,
#    'percent_change_7d': -15.59026344,
#    'percent_change_30d': -10.56044616,
#    'percent_change_60d': -7.21947268,
#    'percent_change_90d': -10.95213058,
#    'market_cap': 2860729705.0527043,
#    'market_cap_dominance': 0.1136,
#    'fully_diluted_market_cap': 3178510503.64,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 40.010933027010914,
#    'volume_24h': 258599240.73470047,
#    'volume_change_24h': -3.4851,
#    'percent_change_1h': -0.45407063,
#    'percent_change_24h': -7.00225678,
#    'percent_change_7d': -17.67622038,
#    'percent_change_30d': -6.10465034,
#    'percent_change_60d': -17.94129449,
#    'percent_change_90d': -28.81142787,
#    'market_cap': 2822324442.944641,
#    'market_cap_dominance': 0.1121,
#    'fully_diluted_market_cap': 4001093302.7,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 232.536533452252,
#    'volume_24h': 90659577.84785119,
#    'volume_change_24h': 63.0194,
#    'percent_change_1h': -1.97560462,
#    'percent_change_24h': -6.92152069,
#    'percent_change_7d': -14.85671686,
#    'percent_change_30d': -17.11372275,
#    'percent_change_60d': -33.41377431,
#    'percent_change_90d': 22.68688772,
#    'market_cap': 2807352643.797274,
#    'market_cap_dominance': 0.1115,
#    'fully_diluted_market_cap': 3397938467.32,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 2828.1496995668863,
#    'volume_24h': 327201345.36844957,
#    'volume_change_24h': 99.5649,
#    'percent_change_1h': -0.46190521,
#    'percent_change_24h': 2.52604654,
#    'percent_change_7d': -6.20313544,
#    'percent_change_30d': 13.46524927,
#    'percent_change_60d': 0.99388285,
#    'percent_change_90d': -24.90640756,
#    'market_cap': 2802179635.421138,
#    'market_cap_dominance': 0.1113,
#    'fully_diluted_market_cap': 2843922290.44,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.44000791750868257,
#    'volume_24h': 663562750.4066911,
#    'volume_change_24h': 1.9525,
#    'percent_change_1h': -1.48019671,
#    'percent_change_24h': -10.46864341,
#    'percent_change_7d': -11.81939783,
#    'percent_change_30d': 40.58605093,
#    'percent_change_60d': 37.0437959,
#    'percent_change_90d': 24.91696934,
#    'market_cap': 2614125797.5700583,
#    'market_cap_dominance': 0.1038,
#    'fully_diluted_market_cap': 3911181488.57,
#    'last_updated': '2021-11-18T20:38:11.000Z'}},
#  {'USD': {'price': 0.23811888216730934,
#    'volume_24h': 221205135.68046224,
#    'volume_change_24h': 41.829,
#    'percent_change_1h': -0.68223384,
#    'percent_change_24h': -8.54336255,
#    'percent_change_7d': -14.25583647,
#    'percent_change_30d': 1.63931151,
#    'percent_change_60d': 50.03728071,
#    'percent_change_90d': 109.62511323,
#    'market_cap': 2571353597.011624,
#    'market_cap_dominance': 0.1021,
#    'fully_diluted_market_cap': 3154898921.24,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 9.939170503712758,
#    'volume_24h': 121358240.11439346,
#    'volume_change_24h': 30.327,
#    'percent_change_1h': -1.02754635,
#    'percent_change_24h': -9.0403581,
#    'percent_change_7d': -22.48557344,
#    'percent_change_30d': 35.29857836,
#    'percent_change_60d': 5.04582403,
#    'percent_change_90d': 6.04903222,
#    'market_cap': 2566395354.097818,
#    'market_cap_dominance': 0.1019,
#    'fully_diluted_market_cap': 4969585251.86,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 1.9522202984501136,
#    'volume_24h': 93192657.42508021,
#    'volume_change_24h': -20.5261,
#    'percent_change_1h': -0.2263014,
#    'percent_change_24h': -8.58414493,
#    'percent_change_7d': -12.11796606,
#    'percent_change_30d': -16.81903234,
#    'percent_change_60d': 36.73958568,
#    'percent_change_90d': 35.84128249,
#    'market_cap': 2508671732.4021096,
#    'market_cap_dominance': 0.0996,
#    'fully_diluted_market_cap': 3549136502.58,
#    'last_updated': '2021-11-18T20:38:07.000Z'}},
#  {'USD': {'price': 2.9919888983092267,
#    'volume_24h': 818493283.5293748,
#    'volume_change_24h': 73.822,
#    'percent_change_1h': -0.92627713,
#    'percent_change_24h': 1.52268029,
#    'percent_change_7d': 0.41808455,
#    'percent_change_30d': 88.79473614,
#    'percent_change_60d': 85.27306179,
#    'percent_change_90d': 82.42745228,
#    'market_cap': 2498635838.308033,
#    'market_cap_dominance': 0.0992,
#    'fully_diluted_market_cap': 2991988898.31,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 21.582483243933765,
#    'volume_24h': 278166314.4790197,
#    'volume_change_24h': 228.2992,
#    'percent_change_1h': -0.96177636,
#    'percent_change_24h': 0.95369243,
#    'percent_change_7d': -11.07565972,
#    'percent_change_30d': -24.22254802,
#    'percent_change_60d': -22.86903314,
#    'percent_change_90d': -10.88242917,
#    'market_cap': 2303534349.8771687,
#    'market_cap_dominance': 0.0915,
#    'fully_diluted_market_cap': 2303534349.88,
#    'last_updated': '2021-11-18T20:39:04.000Z'}},
#  {'USD': {'price': 0.003317250526620277,
#    'volume_24h': 472037622.42586184,
#    'volume_change_24h': 15.0318,
#    'percent_change_1h': -0.8356219,
#    'percent_change_24h': -7.37076431,
#    'percent_change_7d': -13.26630747,
#    'percent_change_30d': -7.01093766,
#    'percent_change_60d': -14.52017895,
#    'percent_change_90d': -25.94319547,
#    'market_cap': 2189228192.825684,
#    'market_cap_dominance': 0.087,
#    'fully_diluted_market_cap': 3284078021.35,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.048772168175661976,
#    'volume_24h': 27303228.76919052,
#    'volume_change_24h': -13.7214,
#    'percent_change_1h': -1.11497143,
#    'percent_change_24h': -4.6217821,
#    'percent_change_7d': -18.33401629,
#    'percent_change_30d': 2.76265058,
#    'percent_change_60d': -0.4955351,
#    'percent_change_90d': -18.71474586,
#    'market_cap': 2059536592.6873608,
#    'market_cap_dominance': 0.0818,
#    'fully_diluted_market_cap': 4513748974.5,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 153.18709891415574,
#    'volume_24h': 493568386.18341535,
#    'volume_change_24h': 3.6558,
#    'percent_change_1h': 1.54051928,
#    'percent_change_24h': -3.13523543,
#    'percent_change_7d': -26.60860002,
#    'percent_change_30d': 9.31260514,
#    'percent_change_60d': 12.8644474,
#    'percent_change_90d': -0.90123759,
#    'market_cap': 2009138799.6797645,
#    'market_cap_dominance': 0.0798,
#    'fully_diluted_market_cap': 3216929077.2,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 0.011576105755546713,
#    'volume_24h': 189946149.85039562,
#    'volume_change_24h': 36.1519,
#    'percent_change_1h': -1.2583629,
#    'percent_change_24h': -7.66798916,
#    'percent_change_7d': -17.02024323,
#    'percent_change_30d': 26.90171981,
#    'percent_change_60d': 21.97606265,
#    'percent_change_90d': 3.20370719,
#    'market_cap': 2001976299.8696754,
#    'market_cap_dominance': 0.0795,
#    'fully_diluted_market_cap': 2056141346.91,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 178.28831021187383,
#    'volume_24h': 381502901.0218838,
#    'volume_change_24h': -10.6698,
#    'percent_change_1h': -0.36368934,
#    'percent_change_24h': -5.86762616,
#    'percent_change_7d': -22.39323015,
#    'percent_change_30d': -6.6157581,
#    'percent_change_60d': -9.64811121,
#    'percent_change_90d': -24.07889667,
#    'market_cap': 1860570186.4046607,
#    'market_cap_dominance': 0.0739,
#    'fully_diluted_market_cap': 3369649063,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 54.84166184069993,
#    'volume_24h': 130273440.56029926,
#    'volume_change_24h': 41.2343,
#    'percent_change_1h': -2.70131056,
#    'percent_change_24h': -5.00959588,
#    'percent_change_7d': -17.50689687,
#    'percent_change_30d': 2.77020788,
#    'percent_change_60d': 12.14344972,
#    'percent_change_90d': 67.29607162,
#    'market_cap': 1831420899.5132837,
#    'market_cap_dominance': 0.0727,
#    'fully_diluted_market_cap': 3619549681.49,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 22.733148501158688,
#    'volume_24h': 77928585.94257437,
#    'volume_change_24h': -2.2832,
#    'percent_change_1h': -1.94080803,
#    'percent_change_24h': -6.24363165,
#    'percent_change_7d': 0.89784028,
#    'percent_change_30d': 64.473196,
#    'percent_change_60d': 96.11679034,
#    'percent_change_90d': 85.48178892,
#    'market_cap': 1821348895.3645754,
#    'market_cap_dominance': 0.0723,
#    'fully_diluted_market_cap': 3867332260.47,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 296.6233148907982,
#    'volume_24h': 163727236.23382634,
#    'volume_change_24h': 1.7124,
#    'percent_change_1h': -0.40939431,
#    'percent_change_24h': -7.25732462,
#    'percent_change_7d': -11.64337717,
#    'percent_change_30d': -1.8962096,
#    'percent_change_60d': -25.08100781,
#    'percent_change_90d': -38.31301259,
#    'market_cap': 1785344663.7873845,
#    'market_cap_dominance': 0.0709,
#    'fully_diluted_market_cap': 2966233148.91,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 5.046788016722766,
#    'volume_24h': 74870690.2140182,
#    'volume_change_24h': 70.7401,
#    'percent_change_1h': -0.44777101,
#    'percent_change_24h': -2.66412994,
#    'percent_change_7d': -16.97856139,
#    'percent_change_30d': -16.28872611,
#    'percent_change_60d': -18.28308591,
#    'percent_change_90d': 59.33473613,
#    'market_cap': 1752738163.309083,
#    'market_cap_dominance': 0.0696,
#    'fully_diluted_market_cap': 5046788016.72,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 3.065558982228733,
#    'volume_24h': 16409727.59724637,
#    'volume_change_24h': -0.5406,
#    'percent_change_1h': -1.05405473,
#    'percent_change_24h': -7.50013298,
#    'percent_change_7d': -11.41175852,
#    'percent_change_30d': 70.07805842,
#    'percent_change_60d': 91.56694683,
#    'percent_change_90d': 61.54645781,
#    'market_cap': 1716713063.7692392,
#    'market_cap_dominance': 0.0682,
#    'fully_diluted_market_cap': 3065558982.23,
#    'last_updated': '2021-11-18T20:39:08.000Z'}},
#  {'USD': {'price': 0.1764283999690553,
#    'volume_24h': 292507296.3067258,
#    'volume_change_24h': -23.3938,
#    'percent_change_1h': -2.02881602,
#    'percent_change_24h': -10.11244743,
#    'percent_change_7d': -1.9038366,
#    'percent_change_30d': 164.67650458,
#    'percent_change_60d': 178.95612443,
#    'percent_change_90d': 115.24248824,
#    'market_cap': 1683264430.6454837,
#    'market_cap_dominance': 0.0668,
#    'fully_diluted_market_cap': 1764283999.69,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 4.0257779825521744,
#    'volume_24h': 485312383.4678773,
#    'volume_change_24h': 10.1837,
#    'percent_change_1h': 3.16158124,
#    'percent_change_24h': 1.78393672,
#    'percent_change_7d': -3.21467356,
#    'percent_change_30d': 49.37546205,
#    'percent_change_60d': 35.71460113,
#    'percent_change_90d': 73.82776508,
#    'market_cap': 1664608000.5541325,
#    'market_cap_dominance': 0.0661,
#    'fully_diluted_market_cap': 13297266653.42,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 0.3131916988463363,
#    'volume_24h': 49409643.08930275,
#    'volume_change_24h': 8.1908,
#    'percent_change_1h': -0.46210182,
#    'percent_change_24h': -5.93851922,
#    'percent_change_7d': -8.62787142,
#    'percent_change_30d': 11.75347511,
#    'percent_change_60d': 3.93478676,
#    'percent_change_90d': -6.99872038,
#    'market_cap': 1660296343.8846614,
#    'market_cap_dominance': 0.0659,
#    'fully_diluted_market_cap': 1660296343.88,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 0.8749717878896371,
#    'volume_24h': 597733334.3946451,
#    'volume_change_24h': -29.6213,
#    'percent_change_1h': -1.89291396,
#    'percent_change_24h': -5.81878181,
#    'percent_change_7d': 63.93737053,
#    'percent_change_30d': 198.9775343,
#    'percent_change_60d': 215.9634259,
#    'percent_change_90d': 383.25574216,
#    'market_cap': 1614783793.7671206,
#    'market_cap_dominance': 0.0641,
#    'fully_diluted_market_cap': 3332490098.35,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 0.1755532034421859,
#    'volume_24h': 175061270.6043919,
#    'volume_change_24h': -16.5124,
#    'percent_change_1h': -0.82273401,
#    'percent_change_24h': -8.03628525,
#    'percent_change_7d': -10.1130077,
#    'percent_change_30d': 6.37039814,
#    'percent_change_60d': -3.25486607,
#    'percent_change_90d': -14.83719836,
#    'market_cap': 1579978830.8041198,
#    'market_cap_dominance': 0.0628,
#    'fully_diluted_market_cap': 1579978830.8,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 9.815821001131912,
#    'volume_24h': 108538125.21962641,
#    'volume_change_24h': -4.2758,
#    'percent_change_1h': -0.83301799,
#    'percent_change_24h': -6.37426902,
#    'percent_change_7d': -2.64317919,
#    'percent_change_30d': 22.72994075,
#    'percent_change_60d': -30.65623427,
#    'percent_change_90d': -33.98052856,
#    'market_cap': 1563744370.3002727,
#    'market_cap_dominance': 0.0621,
#    'fully_diluted_market_cap': 4907910500.57,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 0.9948714960851476,
#    'volume_24h': 251634830.17088997,
#    'volume_change_24h': -16.9854,
#    'percent_change_1h': -0.52178956,
#    'percent_change_24h': -6.70044656,
#    'percent_change_7d': -12.62084724,
#    'percent_change_30d': 46.58271842,
#    'percent_change_60d': 33.9620499,
#    'percent_change_90d': 28.62276662,
#    'market_cap': 1484693813.3618598,
#    'market_cap_dominance': 0.059,
#    'fully_diluted_market_cap': 1492307244.13,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 24.425932244046777,
#    'volume_24h': 475600316.20013785,
#    'volume_change_24h': -20.5458,
#    'percent_change_1h': 0.10414819,
#    'percent_change_24h': -6.6835577,
#    'percent_change_7d': -14.00524581,
#    'percent_change_30d': 25.63712296,
#    'percent_change_60d': 31.74328185,
#    'percent_change_90d': 9.98046527,
#    'market_cap': 1465555934.6428065,
#    'market_cap_dominance': 0.0582,
#    'fully_diluted_market_cap': 7327779673.21,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 107.737501141789,
#    'volume_24h': 12032334.68512488,
#    'volume_change_24h': 1.3518,
#    'percent_change_1h': 0.26637664,
#    'percent_change_24h': -2.17488378,
#    'percent_change_7d': -0.68382893,
#    'percent_change_30d': -11.34189862,
#    'percent_change_60d': -23.93610211,
#    'percent_change_90d': -37.13529609,
#    'market_cap': 1455458657.4839416,
#    'market_cap_dominance': 0.0578,
#    'fully_diluted_market_cap': 2262487523.98,
#    'last_updated': '2021-11-18T20:39:04.000Z'}},
#  {'USD': {'price': 2.079192636831169,
#    'volume_24h': 153056865.17885742,
#    'volume_change_24h': -3.8249,
#    'percent_change_1h': -0.91832476,
#    'percent_change_24h': -8.37641522,
#    'percent_change_7d': 0.57343781,
#    'percent_change_30d': -0.18286786,
#    'percent_change_60d': 13.00971585,
#    'percent_change_90d': 51.83043405,
#    'market_cap': 1403586222.759746,
#    'market_cap_dominance': 0.0557,
#    'fully_diluted_market_cap': 1664310538.08,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 14.042637139762881,
#    'volume_24h': 376218013.4848747,
#    'volume_change_24h': -15.8787,
#    'percent_change_1h': -0.77493041,
#    'percent_change_24h': -7.10628911,
#    'percent_change_7d': -14.07053848,
#    'percent_change_30d': 14.16486088,
#    'percent_change_60d': 13.97489812,
#    'percent_change_90d': 3.69638406,
#    'market_cap': 1388439848.7242842,
#    'market_cap_dominance': 0.0551,
#    'fully_diluted_market_cap': 1514110922.99,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 9.171296146758184,
#    'volume_24h': 884424669.0411233,
#    'volume_change_24h': -36.1474,
#    'percent_change_1h': -1.04191147,
#    'percent_change_24h': -10.53806548,
#    'percent_change_7d': -47.44938953,
#    'percent_change_30d': -33.58238727,
#    'percent_change_60d': -5.6995907,
#    'percent_change_90d': 51.19340005,
#    'market_cap': 1286232080.5261533,
#    'market_cap_dominance': 0.0511,
#    'fully_diluted_market_cap': 1286232087.45,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 1.00008767340353,
#    'volume_24h': 143595542.95653373,
#    'volume_change_24h': -13.1063,
#    'percent_change_1h': 0.03200911,
#    'percent_change_24h': 0.10425361,
#    'percent_change_7d': 0.01152078,
#    'percent_change_30d': -0.01993681,
#    'percent_change_60d': -0.05728137,
#    'percent_change_90d': -0.00046359,
#    'market_cap': 1287020254.2583847,
#    'market_cap_dominance': 0.0511,
#    'fully_diluted_market_cap': 1287020254.26,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 4.258903949303884,
#    'volume_24h': 90654667.46960536,
#    'volume_change_24h': -10.0787,
#    'percent_change_1h': -1.42650981,
#    'percent_change_24h': -9.69605957,
#    'percent_change_7d': -27.93017466,
#    'percent_change_30d': 6.69668964,
#    'percent_change_60d': -20.58327546,
#    'percent_change_90d': 28.50711288,
#    'market_cap': 1264581685.5792472,
#    'market_cap_dominance': 0.0502,
#    'fully_diluted_market_cap': 3509783919.89,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 4.32211041844087,
#    'volume_24h': 100838911.75022809,
#    'volume_change_24h': 913.6691,
#    'percent_change_1h': 19.56348532,
#    'percent_change_24h': 37.94074665,
#    'percent_change_7d': 61.05216674,
#    'percent_change_30d': 88.53074322,
#    'percent_change_60d': 48.12540836,
#    'percent_change_90d': -18.70764805,
#    'market_cap': 1203630879.2824602,
#    'market_cap_dominance': 0.0478,
#    'fully_diluted_market_cap': 1207545660.25,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 0.11862782415128172,
#    'volume_24h': 114684649.76590884,
#    'volume_change_24h': 90.6386,
#    'percent_change_1h': 2.2444858,
#    'percent_change_24h': 1.93424953,
#    'percent_change_7d': -6.65300407,
#    'percent_change_30d': 11.92903442,
#    'percent_change_60d': 5.99945085,
#    'percent_change_90d': -17.47367426,
#    'market_cap': 1199966706.1416335,
#    'market_cap_dominance': 0.0477,
#    'fully_diluted_market_cap': 2491184307.18,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 31608.006515065394,
#    'volume_24h': 426238372.8552801,
#    'volume_change_24h': 134.8907,
#    'percent_change_1h': 0.41668333,
#    'percent_change_24h': 2.51352326,
#    'percent_change_7d': -6.45560705,
#    'percent_change_30d': -7.30533128,
#    'percent_change_60d': -4.85977583,
#    'percent_change_90d': -19.50232647,
#    'market_cap': 1158045331.2047646,
#    'market_cap_dominance': 0.046,
#    'fully_diluted_market_cap': 1158939166.88,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 8.952369092936959,
#    'volume_24h': 358241374.89356166,
#    'volume_change_24h': 71.2287,
#    'percent_change_1h': -1.22003871,
#    'percent_change_24h': -7.94565081,
#    'percent_change_7d': -19.99688133,
#    'percent_change_30d': -15.0239717,
#    'percent_change_60d': -25.97889377,
#    'percent_change_90d': -36.26456173,
#    'market_cap': 1139139218.7611785,
#    'market_cap_dominance': 0.0452,
#    'fully_diluted_market_cap': 2238092273.23,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 2.2393952004788984,
#    'volume_24h': 484966515.85540086,
#    'volume_change_24h': 1352.9246,
#    'percent_change_1h': -2.62137323,
#    'percent_change_24h': 0.49656647,
#    'percent_change_7d': -5.34301558,
#    'percent_change_30d': 17.10712632,
#    'percent_change_60d': -21.6675356,
#    'percent_change_90d': -30.03609247,
#    'market_cap': 1128832021.6015563,
#    'market_cap_dominance': 0.0448,
#    'fully_diluted_market_cap': 2376055728.04,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 0.013188717482011935,
#    'volume_24h': 2741260.1771181,
#    'volume_change_24h': -13.657,
#    'percent_change_1h': -1.95865875,
#    'percent_change_24h': -6.4766566,
#    'percent_change_7d': -10.06692882,
#    'percent_change_30d': -25.06478374,
#    'percent_change_60d': -37.72130721,
#    'percent_change_90d': 13.50173449,
#    'market_cap': 1121851903.363422,
# ...
#  {'USD': {'price': 0.08589588670982228,
#    'volume_24h': 198077.37641408,
#    'volume_change_24h': 17.1387,
#    'percent_change_1h': 0.02858352,
#    'percent_change_24h': 0.74238801,
#    'percent_change_7d': -3.83503423,
#    'percent_change_30d': 1.96267667,
#    'percent_change_60d': -28.2055399,
#    'percent_change_90d': -46.82704803,
#    'market_cap': 16479479.206669508,
#    'market_cap_dominance': 0.0007,
#    'fully_diluted_market_cap': 85895886.71,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 2.785396254860503e-08,
#    'volume_24h': 5710904.2560516,
#    'volume_change_24h': -33.3898,
#    'percent_change_1h': 0.53582211,
#    'percent_change_24h': 9.48873413,
#    'percent_change_7d': 15.92515861,
#    'percent_change_30d': 247.83099547,
#    'percent_change_60d': 109.91978624,
#    'percent_change_90d': 209.08254435,
#    'market_cap': 16445363.124559246,
#    'market_cap_dominance': 0.0007,
#    'fully_diluted_market_cap': 27853962.55,
#    'last_updated': '2021-11-18T20:38:07.000Z'}},
#  {'USD': {'price': 7.080481859844346,
#    'volume_24h': 847243.75489892,
#    'volume_change_24h': 8.0059,
#    'percent_change_1h': -0.48388609,
#    'percent_change_24h': -10.2276302,
#    'percent_change_7d': -23.10864509,
#    'percent_change_30d': 81.63271802,
#    'percent_change_60d': 68.06017346,
#    'percent_change_90d': 210.05227384,
#    'market_cap': 16414950.153987821,
#    'market_cap_dominance': 0.0007,
#    'fully_diluted_market_cap': 283219274.39,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 1.4559949996663117,
#    'volume_24h': 651059.89803658,
#    'volume_change_24h': -33.5231,
#    'percent_change_1h': -0.21154303,
#    'percent_change_24h': -4.32605434,
#    'percent_change_7d': -15.35022143,
#    'percent_change_30d': -8.22863282,
#    'percent_change_60d': -38.04800599,
#    'percent_change_90d': -25.40274615,
#    'market_cap': 16404151.829223914,
#    'market_cap_dominance': 0.0007,
#    'fully_diluted_market_cap': 145599499.97,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.8299443601099935,
#    'volume_24h': 274749.01431682,
#    'volume_change_24h': -34.0689,
#    'percent_change_1h': 0.20249353,
#    'percent_change_24h': -1.92702278,
#    'percent_change_7d': 5.5096886,
#    'percent_change_30d': -0.508226,
#    'percent_change_60d': -15.32528408,
#    'percent_change_90d': 36.25579741,
#    'market_cap': 16399937.919860464,
#    'market_cap_dominance': 0.0007,
#    'fully_diluted_market_cap': 85478788.97,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 0.03258405821240936,
#    'volume_24h': 2145733.51290906,
#    'volume_change_24h': 17.2908,
#    'percent_change_1h': -3.02990079,
#    'percent_change_24h': 0.9955174,
#    'percent_change_7d': -6.46715844,
#    'percent_change_30d': 17.64948862,
#    'percent_change_60d': 15.00605897,
#    'percent_change_90d': 123.25874457,
#    'market_cap': 16161692.873355042,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 32584058.21,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 0.0555489342130514,
#    'volume_24h': 594624.9751505,
#    'volume_change_24h': -8.011,
#    'percent_change_1h': -0.3553374,
#    'percent_change_24h': -1.0540447,
#    'percent_change_7d': -11.09202822,
#    'percent_change_30d': -5.77658078,
#    'percent_change_60d': 13.71512016,
#    'percent_change_90d': -37.55734366,
#    'market_cap': 16276154.142421667,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 555489342.13,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 10.054162666509164,
#    'volume_24h': 90364.2412874,
#    'volume_change_24h': 19.6781,
#    'percent_change_1h': -0.47652543,
#    'percent_change_24h': 0.30588529,
#    'percent_change_7d': -3.93373824,
#    'percent_change_30d': -46.54603672,
#    'percent_change_60d': -15.69849057,
#    'percent_change_90d': -33.27950516,
#    'market_cap': 16154563.521558983,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 60324976,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 0.014426654147557838,
#    'volume_24h': 1841158.41756522,
#    'volume_change_24h': -55.2485,
#    'percent_change_1h': -0.90078429,
#    'percent_change_24h': -6.83080472,
#    'percent_change_7d': 11.1529602,
#    'percent_change_30d': 30.34330787,
#    'percent_change_60d': 10.50743319,
#    'percent_change_90d': 6.11183214,
#    'market_cap': 16073503.74520722,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 28853308.3,
#    'last_updated': '2021-11-18T20:39:02.000Z'}},
#  {'USD': {'price': 0.5483417113004665,
#    'volume_24h': 236332.32277335,
#    'volume_change_24h': 13.454,
#    'percent_change_1h': -0.07196789,
#    'percent_change_24h': -0.27217072,
#    'percent_change_7d': -19.99266891,
#    'percent_change_30d': -16.16564281,
#    'percent_change_60d': -17.70651046,
#    'percent_change_90d': -35.41794017,
#    'market_cap': 15993044.568473376,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 27417085.57,
#    'last_updated': '2021-11-18T20:38:07.000Z'}},
#  {'USD': {'price': 0.440504308817248,
#    'volume_24h': 520898.17915208,
#    'volume_change_24h': 9.1581,
#    'percent_change_1h': -0.82289789,
#    'percent_change_24h': -5.05902925,
#    'percent_change_7d': -23.1606987,
#    'percent_change_30d': 21.3253917,
#    'percent_change_60d': 4.8181938,
#    'percent_change_90d': 12.54202881,
#    'market_cap': 16005408.659789594,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 44050430.88,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.16143719143489202,
#    'volume_24h': 6666695.2562898,
#    'volume_change_24h': -9.0303,
#    'percent_change_1h': -0.81297167,
#    'percent_change_24h': -16.60109813,
#    'percent_change_7d': 3.24129012,
#    'percent_change_30d': 111.11610428,
#    'percent_change_60d': 104.21751569,
#    'percent_change_90d': 34.48975552,
#    'market_cap': 15896898.908334922,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 322874382.87,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.0804449261422921,
#    'volume_24h': 316800.62349519,
#    'volume_change_24h': 2.1146,
#    'percent_change_1h': 0.72257252,
#    'percent_change_24h': -4.29608497,
#    'percent_change_7d': -21.15029739,
#    'percent_change_30d': 5.50513509,
#    'percent_change_60d': -25.35891541,
#    'percent_change_90d': -14.02833179,
#    'market_cap': 15891750.493368443,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 28155724.15,
#    'last_updated': '2021-11-18T20:39:04.000Z'}},
#  {'USD': {'price': 0.00528259376108117,
#    'volume_24h': 1245076.65011675,
#    'volume_change_24h': -7.4448,
#    'percent_change_1h': -1.44030545,
#    'percent_change_24h': -8.83880749,
#    'percent_change_7d': -23.13718803,
#    'percent_change_30d': 1.97175123,
#    'percent_change_60d': 26.80832982,
#    'percent_change_90d': -4.7382056,
#    'market_cap': 15878712.961621769,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 44902046.97,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 0.3778192658507768,
#    'volume_24h': 849810.14509898,
#    'volume_change_24h': 213.6404,
#    'percent_change_1h': 0.52335653,
#    'percent_change_24h': -8.76882196,
#    'percent_change_7d': -14.74770195,
#    'percent_change_30d': -32.50740123,
#    'percent_change_60d': -13.73366422,
#    'percent_change_90d': -19.29921988,
#    'market_cap': 15855534.218610229,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 151127706.34,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 0.034846899224467216,
#    'volume_24h': 84343.14211623,
#    'volume_change_24h': 70.7889,
#    'percent_change_1h': -0.38040887,
#    'percent_change_24h': 3.73329456,
#    'percent_change_7d': 14.46533564,
#    'percent_change_30d': -3.09974578,
#    'percent_change_60d': -16.13358932,
#    'percent_change_90d': -54.03733453,
#    'market_cap': 15694441.813831823,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 104540697.67,
#    'last_updated': '2021-11-18T20:39:06.000Z'}},
#  {'USD': {'price': 6.952753061209238e-05,
#    'volume_24h': 36765259.67219334,
#    'volume_change_24h': 12.4215,
#    'percent_change_1h': 0.04834307,
#    'percent_change_24h': -0.35761925,
#    'percent_change_7d': -0.48843247,
#    'percent_change_30d': -2.14864749,
#    'percent_change_60d': -0.15565757,
#    'percent_change_90d': -0.27801695,
#    'market_cap': 15693436.919087734,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 21949841.41,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.3530450128819046,
#    'volume_24h': 1308527.97782091,
#    'volume_change_24h': -15.4065,
#    'percent_change_1h': 6.15185929,
#    'percent_change_24h': -13.77484167,
#    'percent_change_7d': -0.33004574,
#    'percent_change_30d': -14.51078987,
#    'percent_change_60d': -71.89161427,
#    'percent_change_90d': -70.21076236,
#    'market_cap': 15603328.845639182,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 353045012.88,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 0.14915356792281453,
#    'volume_24h': 17505337.93768893,
#    'volume_change_24h': 744.2951,
#    'percent_change_1h': 2.54560481,
#    'percent_change_24h': 60.82735532,
#    'percent_change_7d': 38.11692314,
#    'percent_change_30d': 162.57420272,
#    'percent_change_60d': 61.28071859,
#    'percent_change_90d': 2072.98712993,
#    'market_cap': 15508817.211778983,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 146710545.54,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.27781490397707,
#    'volume_24h': 99619.58955705,
#    'volume_change_24h': -18.8328,
#    'percent_change_1h': -0.53669145,
#    'percent_change_24h': -4.77087387,
#    'percent_change_7d': -13.34014526,
#    'percent_change_30d': 0.23670331,
#    'percent_change_60d': 4.67343433,
#    'percent_change_90d': 6.81707032,
#    'market_cap': 15519741.924257183,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 38894086.56,
#    'last_updated': '2021-11-18T20:39:04.000Z'}},
#  {'USD': {'price': 0.005345587550223234,
#    'volume_24h': 581858.09688107,
#    'volume_change_24h': 2437.9833,
#    'percent_change_1h': 0.20517495,
#    'percent_change_24h': 6.55274187,
#    'percent_change_7d': -10.85841095,
#    'percent_change_30d': 8.28585945,
#    'percent_change_60d': 49.57490036,
#    'percent_change_90d': -37.17674227,
#    'market_cap': 15494357.002641609,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 32073525.3,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 1.0975887173124155,
#    'volume_24h': 317127.00903202,
#    'volume_change_24h': -14.1289,
#    'percent_change_1h': 0.23297533,
#    'percent_change_24h': -8.57248965,
#    'percent_change_7d': -20.64777007,
#    'percent_change_30d': -17.78121931,
#    'percent_change_60d': 0.29534725,
#    'percent_change_90d': -2.33621601,
#    'market_cap': 15407617.20399026,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 24146951.78,
#    'last_updated': '2021-11-18T20:39:05.000Z'}},
#  {'USD': {'price': 155.942787598154,
#    'volume_24h': 448140.92963292,
#    'volume_change_24h': 5837.55,
#    'percent_change_1h': -0.01766653,
#    'percent_change_24h': -10.6657831,
#    'percent_change_7d': -9.60221795,
#    'percent_change_30d': -12.59914562,
#    'percent_change_60d': -5.51923946,
#    'percent_change_90d': -4.61141965,
#    'market_cap': 15359096.39849293,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 15359096.4,
#    'last_updated': '2021-11-18T20:38:09.000Z'}},
#  {'USD': {'price': 0.004319979056360724,
#    'volume_24h': 9843.17564708,
#    'volume_change_24h': 27.1153,
#    'percent_change_1h': 0.69368171,
#    'percent_change_24h': -0.00991465,
#    'percent_change_7d': -3.90715588,
#    'percent_change_30d': 69.68296655,
#    'percent_change_60d': 32.96066761,
#    'percent_change_90d': 109.05897623,
#    'market_cap': 15296667.023926394,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 43199790.56,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.21192633640560768,
#    'volume_24h': 224644.3267197,
#    'volume_change_24h': -15.8171,
#    'percent_change_1h': 0.60461914,
#    'percent_change_24h': -10.2723306,
#    'percent_change_7d': -20.41868765,
#    'percent_change_30d': -22.56319632,
#    'percent_change_60d': -60.84759189,
#    'percent_change_90d': -47.52984709,
#    'market_cap': 15218026.045521237,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 31788950.46,
#    'last_updated': '2021-11-18T20:39:04.000Z'}},
#  {'USD': {'price': 0.470696580311399,
#    'volume_24h': 952140.82741212,
#    'volume_change_24h': -12.6513,
#    'percent_change_1h': -2.73617713,
#    'percent_change_24h': -12.21934286,
#    'percent_change_7d': -26.21683429,
#    'percent_change_30d': 25.58278116,
#    'percent_change_60d': 22.22514271,
#    'percent_change_90d': -24.47881449,
#    'market_cap': 15132895.057011478,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 47069658.03,
#    'last_updated': '2021-11-18T20:38:10.000Z'}},
#  {'USD': {'price': 1.4896377296550023,
#    'volume_24h': 7789.11109619,
#    'volume_change_24h': -29.9632,
#    'percent_change_1h': -0.72615524,
#    'percent_change_24h': -3.92869082,
#    'percent_change_7d': -10.01272888,
#    'percent_change_30d': 3.6571364,
#    'percent_change_60d': -8.75950598,
#    'percent_change_90d': -24.70612007,
#    'market_cap': 15080800.358463911,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 15080800.36,
#    'last_updated': '2021-11-18T20:39:03.000Z'}},
#  {'USD': {'price': 0.6004861404332555,
#    'volume_24h': 3043537.9579761,
#    'volume_change_24h': 1.1749,
#    'percent_change_1h': 0.51117452,
#    'percent_change_24h': -8.02298821,
#    'percent_change_7d': -17.88027501,
#    'percent_change_30d': -50.63572872,
#    'percent_change_60d': -21.10491038,
#    'percent_change_90d': -31.32354222,
#    'market_cap': 15066630.213977635,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 24019445.62,
#    'last_updated': '2021-11-18T20:39:07.000Z'}},
#  {'USD': {'price': 0.02786019061580374,
#    'volume_24h': 164106.02337465,
#    'volume_change_24h': -38.235,
#    'percent_change_1h': 0.03253073,
#    'percent_change_24h': -4.76315836,
#    'percent_change_7d': -15.3046333,
#    'percent_change_30d': -16.24503196,
#    'percent_change_60d': -28.06746131,
#    'percent_change_90d': -28.06746131,
#    'market_cap': 15044502.93253402,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 27860190.62,
#    'last_updated': '2021-11-18T20:38:08.000Z'}},
#  {'USD': {'price': 0.030055386574282784,
#    'volume_24h': 2125786.46394592,
#    'volume_change_24h': 89.2411,
#    'percent_change_1h': 0.89483517,
#    'percent_change_24h': -6.10961383,
#    'percent_change_7d': -6.66160354,
#    'percent_change_30d': -21.58215161,
#    'percent_change_60d': -59.79900274,
#    'percent_change_90d': -37.09320901,
#    'market_cap': 15027693.287141392,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 30055386.57,
#    'last_updated': '2021-11-18T20:38:07.000Z'}},
#  {'USD': {'price': 0.00043789484751042147,
#    'volume_24h': 1897746.02209204,
#    'volume_change_24h': 267.681,
#    'percent_change_1h': 10.69495198,
#    'percent_change_24h': 27.18644757,
#    'percent_change_7d': 37.89213068,
#    'percent_change_30d': 50.39547016,
#    'percent_change_60d': 23.81765273,
#    'percent_change_90d': -50.86407504,
#    'market_cap': 14917532.20083269,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 245339772.83,
#    'last_updated': '2021-11-18T20:38:11.000Z'}},
#  {'USD': {'price': 0.06301969510928497,
#    'volume_24h': 1606938.76620055,
#    'volume_change_24h': 159.7544,
#    'percent_change_1h': 0.22017608,
#    'percent_change_24h': 7.23574391,
#    'percent_change_7d': -5.69879691,
#    'percent_change_30d': 52.89110521,
#    'percent_change_60d': 61.02288273,
#    'percent_change_90d': 30.56160303,
#    'market_cap': 14974739.111229189,
#    'market_cap_dominance': 0.0006,
#    'fully_diluted_market_cap': 630196951.09,
#    'last_updated': '2021-11-18T20:39:06.000Z'}}]

# %%
for

# %%
cryptocurrency = 'BTC'
crypto_symbols = pd.DataFrame(
    columns = {
        'symbol' : crypto_df['symbol'],
    },
    data = crypto_df 
)
crypto_symbols
# Out:
#     symbol
# 0      BTC
# 1      ETH
# 2      BNB
# 3     USDT
# 4      SOL
# ..     ...
# 995   NAFT
# 996   IPAD
# 997  LAYER
# 998   BSCS
# 999  TOWER
#
# [1000 rows x 1 columns]

# %%
# int corresponds to the crypto on the latest list
crypto_df['quote'][0]['USD']['price']
# Out:
# 57994.65587997932
